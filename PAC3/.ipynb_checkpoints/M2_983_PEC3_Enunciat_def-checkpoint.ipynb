# %% [markdown]
# <div style="width: 100%; clear: both;">
# <div style="float: left; width: 50%;">
# <img src="http://www.uoc.edu/portal/_resources/common/imatges/marca_UOC/UOC_Masterbrand.jpg", align="left">
# </div>
# <div style="float: right; width: 50%;">
# <p style="margin: 0; padding-top: 22px; text-align:right;">M2.983 · Aprenentatge per reforç</p>
# <p style="margin: 0; text-align:right;">2024-1 · Màster universitari en Ciència de dades (<i>Data science</i>)</p>
# <p style="margin: 0; text-align:right; padding-bottom: 100px;">Estudis d'Informàtica, Multimèdia i Telecomunicació</p>
# <p style="margin: 0; text-align:right; padding-bottom: 100px;">Xavier Maltas Tarridas</p>
# </div>
# </div>
# <div style="width:100%;">&nbsp;</div>
#
# # PEC3: Deep Reinforcement Learning (II)
#
# L'objectiu d'aquesta pràctica és utilitzar la llibreria [stable baselines 3](https://stable-baselines3.readthedocs.io/en/master/), que ja te implementats algoritmes d'aprenentatge per reforç, per solucionar una versió modificada del cartpole, anomenada cartpole target. Els objectius d'aquesta pràctica són:
# <ol>
#     <li>Desenvolupar una capacitat analítica sobre com està funcionant el model.</li>
#     <li>Familiaritzar-se amb la llibreria stable baselines 3.</li>
#     <li>Analitzar l'efecte de modificar la funció de recompensa durant l'entrenament de l'agent.</li>
#     <li>Analitzar l'efecte de modificar l'espai d'accions.</li>
#     <li>Ser capaços de realitzar una cerca d'hiperparàmetres.</li>
#     <li>(Opcional) Familiaritzar-se amb l'anàlisi mitjançant tensorboard.</li>
# </ol>
#
# **Important: El lliurament s'ha de fer en format notebook i en format html on es vegi el codi i els resultats i comentaris de cada exercici. Per exportar el notebook a html es pot fer des del menú File → Download as → HTML.**

# %% [markdown]
# # 0. Cartpole target (2 punts)
#
# En aquesta pràctica utilitzarem un entorn anomenat cartpole random target. Aquest entorn està fora de la llibreria gymnasium i és una modificació de l'entorn [cartpole](https://gymnasium.farama.org/environments/classic_control/cart_pole/). En aquest entorn, l'objectiu no només és mantenir el pal estable, sinó que el carro ha d'estar el més a prop possible d'un punt objectiu, el qual es pot observar marcat en verd quan es renderitza l'entorn:
#
# ![image.png](image.png)
#
# Hi ha alguns paràmetres en l'entorn que permeten regular com de rellevant volem que sigui el punt objectiu, fins al punt que podem aconseguir que aquesta modificació es comporti com el cartpole original.

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong>Exercici 0.1 (0.75 punts):</strong> Llegeix el codi de l'entorn que es proporciona a continuació detingudament. Ignoreu tots els TODOS, són coses que haurem d'implementar a mesura que la pràctica avanci. Després, responeu les següents preguntes:
#     <ul>
#       <li>Quin és l'espai d'observacions? Com es distingeix respecte a la versió bàsica de cartpole?</li>
#       <li>Quines dues versions de la reward existeixen en l'entorn?</li>
#       <li>Per al cas en que la reward és custom, què fa el paràmetre target_desire_factor?</li>
#     </ul>
# </div>

# %%
"""
Classic cart-pole system implemented by Rich Sutton et al.
Copied from http://incompleteideas.net/sutton/book/code/pole.c
permalink: https://perma.cc/C9ZM-652R
"""

import math
from typing import Optional, Union

import numpy as np

import gymnasium as gym
from gymnasium import spaces
from gymnasium.envs.classic_control import utils
from gymnasium.error import DependencyNotInstalled



class CartPoleEnvRandomTarget(gym.Env[np.ndarray, Union[int, np.ndarray]]):
    """
    ## Description

    This environment corresponds to a modification of the version of the cart-pole problem described by Barto, Sutton, and Anderson in
    ["Neuronlike Adaptive Elements That Can Solve Difficult Learning Control Problem"](https://ieeexplore.ieee.org/document/6313077).
    A pole is attached by an un-actuated joint to a cart, which moves along a frictionless track.
    The pendulum is placed upright on the cart and the goal is to balance the pole by applying forces
     in the left and right direction on the cart.
     The modification consists on a target appearing into scene. The cart must be as close to the target as posible

    For more details about original cartpole look for source code in gymnasium.
    """


    metadata = {
        "render_modes": ["human", "rgb_array"],
        "render_fps": 50,
    }

    def __init__(
        self,
        target_desire_factor: float = 0.5,
        reward_function: str = "default",
        is_eval=False,
        increased_actions=False,
        render_mode: Optional[str] = None,
    ):

        self.gravity = 9.8
        self.masscart = 1.0
        self.masspole = 0.1
        self.total_mass = self.masspole + self.masscart
        self.length = 0.5  # actually half the pole's length
        self.polemass_length = self.masspole * self.length
        self.force_mag = 10.0
        self.tau = 0.02  # seconds between state updates

        self.max_steps = 500
        self.steps = 0

        # Angle at which to fail the episode
        self.theta_threshold_radians = 12 * 2 * math.pi / 360
        self.x_threshold = 2.4
        self.target_threshold = 2

        high = np.array(
            [
                self.x_threshold * 2,
                np.inf,
                self.theta_threshold_radians * 2,
                np.inf,
                self.target_threshold * 2,
            ],
            dtype=np.float32,
        )
        self.increased_actions = increased_actions
        if self.increased_actions:
            #TODO 3.1: Ampliar l'espai d'observacions
            raise NotImplementedError("Increased actions should be implemented")
        else:
            self.action_space = spaces.Discrete(2)
        self.observation_space = spaces.Box(-high, high, dtype=np.float32)

        self.render_mode = render_mode

        self.screen_width = 600
        self.screen_height = 400
        self.screen = None
        self.clock = None
        self.isopen = True
        self.state: np.ndarray | None = None

        self.steps_beyond_terminated = None

        #TODO 1.3: Tenir en compte si l'entorn és d'avaluació
        self.is_eval = is_eval
        self.target_position = self.generate_random_target_position()

        self.target_desire_factor = min(
            max(target_desire_factor, 0), 1
        )  # between 0 and 1
        if reward_function in ["default", "custom"]:
            self.reward_function = reward_function
        else:
            raise AttributeError("reward function must be either default or custom")

    def generate_random_target_position(
        self,
    ):
        if self.is_eval:
            #TODO 1.3:Tingueu en compte si l'entorn és d'avaluació per situar el target en unes posicions concretes.
            raise NotImplementedError("You should implement is_eval casuistic")
            return target_position
        else:
            return np.random.uniform(-self.x_threshold, self.x_threshold)

    def custom_reward(self, target_position, current_position, angle, terminated):
        if self.reward_function == "default":
            #Reward default del cartpole
            return 1 if not terminated else 0
        else:
            angle_reward = (
                -abs(angle) / (2.0 * self.x_threshold) / self.theta_threshold_radians
            )
            target_reward = -(abs(target_position - current_position) ** 2) / (
                (2 * self.x_threshold) ** 2
            )
            return (
                1
                + self.target_desire_factor * target_reward
                + (1 - self.target_desire_factor) * angle_reward
            )
        #TODO 2.2: Implementar 2 funcions de reward extra

    def step(self, action):
        assert self.action_space.contains(
            action
        ), f"{action!r} ({type(action)}) invalid"
        assert self.state is not None, "Call reset before using step method."
        x, x_dot, theta, theta_dot, _ = self.state
        if self.increased_actions:
            force_factor = action - 3
            force = (
                force_factor / 3 * self.force_mag
                if force_factor > 0
                else (force_factor - 1) / 3 * self.force_mag
            )
        else:
            force = self.force_mag if action == 1 else -self.force_mag
        costheta = np.cos(theta)
        sintheta = np.sin(theta)

        # For the interested reader:
        # https://coneural.org/florian/papers/05_cart_pole.pdf
        temp = (
            force + self.polemass_length * np.square(theta_dot) * sintheta
        ) / self.total_mass
        thetaacc = (self.gravity * sintheta - costheta * temp) / (
            self.length
            * (4.0 / 3.0 - self.masspole * np.square(costheta) / self.total_mass)
        )
        xacc = temp - self.polemass_length * thetaacc * costheta / self.total_mass

        x = x + self.tau * x_dot
        x_dot = x_dot + self.tau * xacc
        theta = theta + self.tau * theta_dot
        theta_dot = theta_dot + self.tau * thetaacc

        self.state = np.array(
            (x, x_dot, theta, theta_dot, self.target_position), dtype=np.float64
        ) #Aquest estat es diferent respecte al del cartpole original

        terminated = bool(
            x < -self.x_threshold
            or x > self.x_threshold
            or theta < -self.theta_threshold_radians
            or theta > self.theta_threshold_radians
        )

        reward = self.custom_reward(self.target_position, x, theta, terminated)

        if self.render_mode == "human":
            self.render()

        # truncation=False as the time limit is handled by the `TimeLimit` wrapper added during `make`
        self.steps += 1
        if self.steps >= self.max_steps:
            truncated = True
        else:
            truncated = False
        return np.array(self.state, dtype=np.float32), reward, terminated, truncated, {}

    def reset(
        self,
        *,
        seed: Optional[int] = None,
        options: Optional[dict] = None,
    ):

        super().reset(seed=seed)
        self.steps = 0
        # Note that if you use custom reset bounds, it may lead to out-of-bound
        # state/observations.
        low, high = utils.maybe_parse_reset_bounds(
            options, -0.05, 0.05  # default low
        )  # default high

        self.state = self.np_random.uniform(low=low, high=high, size=(4,)).tolist()
        self.steps_beyond_terminated = None

        #Generar posició aleatòria del target i guardar en l'estat
        self.target_position = self.generate_random_target_position()
        self.state.append(self.target_position)

        self.state = np.array(self.state)
        if self.render_mode == "human":
            self.render()
        return np.array(self.state, dtype=np.float32), {}

    def render(self):
        if self.render_mode is None:
            assert self.spec is not None
            gym.logger.warn(
                "You are calling render method without specifying any render mode. "
                "You can specify the render_mode at initialization, "
                f'e.g. gym.make("{self.spec.id}", render_mode="rgb_array")'
            )
            return

        try:
            import pygame
            from pygame import gfxdraw
        except ImportError as e:
            raise DependencyNotInstalled(
                'pygame is not installed, run `pip install "gymnasium[classic-control]"`'
            ) from e

        if self.screen is None:
            pygame.init()
            if self.render_mode == "human":
                pygame.display.init()
                self.screen = pygame.display.set_mode(
                    (self.screen_width, self.screen_height)
                )
            else:  # mode == "rgb_array"
                self.screen = pygame.Surface((self.screen_width, self.screen_height))
        if self.clock is None:
            self.clock = pygame.time.Clock()

        world_width = self.x_threshold * 2
        scale = self.screen_width / world_width
        polewidth = 10.0
        polelen = scale * (2 * self.length)
        cartwidth = 50.0
        cartheight = 30.0
        targetwidth = 10
        targetheight = 10

        if self.state is None:
            return None

        x = self.state

        self.surf = pygame.Surface((self.screen_width, self.screen_height))
        self.surf.fill((255, 255, 255))

        l, r, t, b = -cartwidth / 2, cartwidth / 2, cartheight / 2, -cartheight / 2
        axleoffset = cartheight / 4.0
        cartx = x[0] * scale + self.screen_width / 2.0  # MIDDLE OF CART
        carty = 100  # TOP OF CART
        cart_coords = [(l, b), (l, t), (r, t), (r, b)]
        cart_coords = [(c[0] + cartx, c[1] + carty) for c in cart_coords]
        gfxdraw.aapolygon(self.surf, cart_coords, (0, 0, 0))
        gfxdraw.filled_polygon(self.surf, cart_coords, (0, 0, 0))

        l, r, t, b = (
            -polewidth / 2,
            polewidth / 2,
            polelen - polewidth / 2,
            -polewidth / 2,
        )

        pole_coords = []
        for coord in [(l, b), (l, t), (r, t), (r, b)]:
            coord = pygame.math.Vector2(coord).rotate_rad(-x[2])
            coord = (coord[0] + cartx, coord[1] + carty + axleoffset)
            pole_coords.append(coord)
        gfxdraw.aapolygon(self.surf, pole_coords, (202, 152, 101))
        gfxdraw.filled_polygon(self.surf, pole_coords, (202, 152, 101))

        gfxdraw.aacircle(
            self.surf,
            int(cartx),
            int(carty + axleoffset),
            int(polewidth / 2),
            (129, 132, 203),
        )
        gfxdraw.filled_circle(
            self.surf,
            int(cartx),
            int(carty + axleoffset),
            int(polewidth / 2),
            (129, 132, 203),
        )

        l, r, t, b = (
            -targetwidth / 2,
            targetwidth / 2,
            targetheight / 2,
            -targetheight / 2,
        )
        axleoffset = targetheight / 4.0
        targetx = x[-1] * scale + self.screen_width / 2.0  # MIDDLE OF target
        targety = 90  # TOP OF target
        target_coords = [(l, b), (l, t), (r, t), (r, b)]
        target_coords = [(c[0] + targetx, c[1] + targety) for c in target_coords]
        gfxdraw.aapolygon(self.surf, target_coords, (10, 255, 10))
        gfxdraw.filled_polygon(self.surf, target_coords, (10, 255, 10))

        gfxdraw.hline(self.surf, 0, self.screen_width, carty, (0, 0, 0))

        self.surf = pygame.transform.flip(self.surf, False, True)
        self.screen.blit(self.surf, (0, 0))
        if self.render_mode == "human":
            pygame.event.pump()
            self.clock.tick(self.metadata["render_fps"])
            pygame.display.flip()

        elif self.render_mode == "rgb_array":
            return np.transpose(
                np.array(pygame.surfarray.pixels3d(self.screen)), axes=(1, 0, 2)
            )

    def close(self):
        if self.screen is not None:
            import pygame

            pygame.display.quit()
            pygame.quit()
            self.isopen = False

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>Comentari:</strong>
# <br><br>
#
# 1.**Espai d'observacions**:
#
# L'espai d'observacions es tracta d'una caixa (Box) amb els límits següents:
#
# * Posició del carro: entre -4.8 i 4.8.
# * Velocitat del carro: entre -infinit i infinit.
# * Angle del pal: entre -24º i 24º (radians).
# * Velocitat angular del pal: entre -infinit i infinit.
# * Posició del target: entre -4.8 i 4.8.
#
# Definició, creació i assiganció dels límits de l'espai d'observació:
#
# ```
# #Definition
# high = np.array(
#     [
#         self.x_threshold * 2,  # Límit per la posició del carro
#         np.inf,                # Límit per la velocitat del carro
#         self.theta_threshold_radians * 2,  # Límit per l'angle del pal
#         np.inf,                # Límit per la velocitat angular del pal
#         self.target_threshold * 2,  # Límit per la posició del target
#     ],
#     dtype=np.float32,
# )
#
# #Creation
# self.observation_space = spaces.Box(-high, high, dtype=np.float32)
#
# #Assignment
# self.state = np.array(
#     (x, x_dot, theta, theta_dot, self.target_position), dtype=np.float64
# )
#
# ```
#
# Aquest espai d'observacions es distingeix de la versió bàsica de 'cartpole' perquè inclou la posició del target com a una dimensió addicional. La versió original inclou 4 elements: posició del carro, velocitat del carro, angle del pal i velocitat del pal.
#
# 2.**Reward**:
#
# Hi ha dues versions de la funció de recompensa en aquest entorn:
#
# * _Default_ : Recompensa similar a la de la versió bàsica del 'cartpole'. La recompensa és 1 per a cada pas que el pal es manté dret i no ha acabat l'episodi.
#
# ```
# if self.reward_function == "default":
#     return 1 if not terminated else 0
# ```
#
# * _Custom_ : La recompensa es calcula considerant la proximitat al target i l'angle del pal. Es calcula de la següent manera:
#
# ```
# angle_reward = (
#     -abs(angle) / (2.0 * self.x_threshold) / self.theta_threshold_radians
# )
# target_reward = -(abs(target_position - current_position) ** 2) / (
#     (2 * self.x_threshold) ** 2
# )
# return (
#     1
#     + self.target_desire_factor * target_reward
#     + (1 - self.target_desire_factor) * angle_reward
# )
# ```
#
# Quan ens trobem en el cas de la recompensa custom, el paràmetre 'target_desire_factor' determina el pes relatiu entre la proximitat al target i l'angle del pal. Un valor més alt fa que la recompensa depengui més de la proximitat al target, mentre que un valor més baix fa que la recompensa depengui més de l'angle del pal.
#
#
# </div>

# %% [markdown]
# <strong>IMPORTANT: PER ALS APARTATS 1 I 2 FAREM SERVIR LA REWARD DEFAULT.</strong> Això implica que el nostre entorn serà el mateix que el del cartpole clàssic sense target.

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong>Exercici 0.2 (0.75 punts):</strong> Executa l'entorn cartpole target utilitzant una policy random. Desa les observacions en una llista i posteriorment crea una funció per analitzar els resultats on es vegi:
#     <ul>
#     <li>Un scatter plot dels angles del pal així com la posició relativa del carro respecte al target. Heu de marcar el punt inicial i final. De manera opcional, podeu marcar cada punt de forma diferent segons l'acció presa (empujar a l'esquerra o a la dreta). Per exemple, una creu si es prem a la dreta i un cercle si es fa cap a l'esquerra).</li>
#     <li>L'evolució de la reward.</li>
#     <li>Imprimir el número de steps realitzats.</li>
#     </ul>
# Comenta els resultats trobats.
#
# <strong>NOTA: Per poder veure com l'agent va movent el Pal de manera interactiva, podeu utilitzar render_mode = 'human'. Això NO s'ha de fer quan s'entrenin els models, ja que seran molt lents d'entrenar.
#
# No és obligatori utilitzar render_mode = 'human' per a les avaluacions, però pot ser interessant. En cas de voler-ho fer, recordeu que cal executar-ho localment.</strong>
# </div>

# %%
import gymnasium as gym
import time

# %%
#TODO: Completar codi
env = CartPoleEnvRandomTarget(render_mode='human',reward_function = 'default')

#Init variables
observations = []
current_step = [] #temporary storage
rewards = []
actions = []
steps = 0

#Reset env
state, _ = env.reset()
done = False

while not done:
    #random action
    action = env.action_space.sample() 
    actions.append(action) #save action

    #Info before step
    print(f"Step: {steps}, Action: {action}, State: {state}")

    #execute action
    next_state, reward, terminated, truncated, _ = env.step(action)

    #Status after step
    print(f"Next State: {next_state}, Reward: {reward}, Terminated: {terminated}, Truncated: {truncated}\n")

    current_step.append((state,action)) #save temporary state-action pair
    rewards.append(reward)#save reward
    
    #Check episode end
    if terminated or truncated:
        print("Episode ended.")
        done = True
        observations.append(current_step)
        break
        
    steps += 1 #increase steps
    state = next_state #next state to current state for next step

#Close env
env.close()

#Print steps
print(f"Number of steps taken: {steps}")

# # Print the values of observations and rewards
# print("\nObservations:")
# for episode in observations:
#     for step in episode:
#         print(step)

# print("\nRewards:")
# print(rewards)

# Convertim les observacions a un format numpy per facilitar l'anàlisi
observations = np.array(observations, dtype=object) 
rewards = np.array(rewards)
# Out:
# Step: 0, Action: 0, State: [ 0.02330831  0.03441427 -0.01754698 -0.01561026  0.29285192]
# Next State: [ 0.0239966  -0.1604517  -0.01785918  0.27148515  0.29285192], Reward: 1, Terminated: False, Truncated: False
#
# Step: 1, Action: 1, State: [ 0.0239966  -0.1604517  -0.01785918  0.27148515  0.29285192]
# Next State: [ 0.02078756  0.03492048 -0.01242948 -0.02677671  0.29285192], Reward: 1, Terminated: False, Truncated: False
#
# Step: 2, Action: 0, State: [ 0.02078756  0.03492048 -0.01242948 -0.02677671  0.29285192]
# Next State: [ 0.02148597 -0.16002104 -0.01296501  0.2619588   0.29285192], Reward: 1, Terminated: False, Truncated: False
#
# Step: 3, Action: 1, State: [ 0.02148597 -0.16002104 -0.01296501  0.2619588   0.29285192]
# Next State: [ 0.01828555  0.03528356 -0.00772584 -0.03478507  0.29285192], Reward: 1, Terminated: False, Truncated: False
#
# Step: 4, Action: 1, State: [ 0.01828555  0.03528356 -0.00772584 -0.03478507  0.29285192]
# Next State: [ 0.01899122  0.23051545 -0.00842154 -0.32989553  0.29285192], Reward: 1, Terminated: False, Truncated: False
#
# Step: 5, Action: 0, State: [ 0.01899122  0.23051545 -0.00842154 -0.32989553  0.29285192]
# Next State: [ 0.02360153  0.03551438 -0.01501945 -0.03988022  0.29285192], Reward: 1, Terminated: False, Truncated: False
#
# Step: 6, Action: 1, State: [ 0.02360153  0.03551438 -0.01501945 -0.03988022  0.29285192]
# Next State: [ 0.02431182  0.23084846 -0.01581706 -0.33726382  0.29285192], Reward: 1, Terminated: False, Truncated: False
#
# Step: 7, Action: 1, State: [ 0.02431182  0.23084846 -0.01581706 -0.33726382  0.29285192]
# Next State: [ 0.02892879  0.42619187 -0.02256233 -0.63489234  0.29285192], Reward: 1, Terminated: False, Truncated: False
#
# Step: 8, Action: 1, State: [ 0.02892879  0.42619187 -0.02256233 -0.63489234  0.29285192]
# Next State: [ 0.03745262  0.62162113 -0.03526018 -0.9345944   0.29285192], Reward: 1, Terminated: False, Truncated: False
#
# Step: 9, Action: 1, State: [ 0.03745262  0.62162113 -0.03526018 -0.9345944   0.29285192]
# Next State: [ 0.04988505  0.81720054 -0.05395206 -1.2381455   0.29285192], Reward: 1, Terminated: False, Truncated: False
#
# Step: 10, Action: 0, State: [ 0.04988505  0.81720054 -0.05395206 -1.2381455   0.29285192]
# Next State: [ 0.06622906  0.62281156 -0.07871497 -0.96284044  0.29285192], Reward: 1, Terminated: False, Truncated: False
#
# Step: 11, Action: 0, State: [ 0.06622906  0.62281156 -0.07871497 -0.96284044  0.29285192]
# Next State: [ 0.07868529  0.42883047 -0.09797178 -0.6958881   0.29285192], Reward: 1, Terminated: False, Truncated: False
#
# Step: 12, Action: 0, State: [ 0.07868529  0.42883047 -0.09797178 -0.6958881   0.29285192]
# Next State: [ 0.0872619   0.23519395 -0.11188955 -0.43558386  0.29285192], Reward: 1, Terminated: False, Truncated: False
#
# Step: 13, Action: 1, State: [ 0.0872619   0.23519395 -0.11188955 -0.43558386  0.29285192]
# Next State: [ 0.09196578  0.43170726 -0.12060122 -0.7613375   0.29285192], Reward: 1, Terminated: False, Truncated: False
#
# Step: 14, Action: 0, State: [ 0.09196578  0.43170726 -0.12060122 -0.7613375   0.29285192]
# Next State: [ 0.10059992  0.23843485 -0.13582797 -0.50890553  0.29285192], Reward: 1, Terminated: False, Truncated: False
#
# Step: 15, Action: 1, State: [ 0.10059992  0.23843485 -0.13582797 -0.50890553  0.29285192]
# Next State: [ 0.10536862  0.43518272 -0.14600609 -0.8411199   0.29285192], Reward: 1, Terminated: False, Truncated: False
#
# Step: 16, Action: 1, State: [ 0.10536862  0.43518272 -0.14600609 -0.8411199   0.29285192]
# Next State: [ 0.11407227  0.6319638  -0.16282848 -1.1759243   0.29285192], Reward: 1, Terminated: False, Truncated: False
#
# Step: 17, Action: 1, State: [ 0.11407227  0.6319638  -0.16282848 -1.1759243   0.29285192]
# Next State: [ 0.12671155  0.82878274 -0.18634696 -1.514908    0.29285192], Reward: 1, Terminated: False, Truncated: False
#
# Step: 18, Action: 1, State: [ 0.12671155  0.82878274 -0.18634696 -1.514908    0.29285192]
# Next State: [ 0.1432872   1.0256065  -0.21664512 -1.859502    0.29285192], Reward: 0, Terminated: True, Truncated: False
#
# Episode ended.
# Number of steps taken: 18

# %%
import numpy as np
import matplotlib.pylab as plt
X_THRESHOLD = env.unwrapped.x_threshold*1.25 #Limit de posicio del carro
ANGLE_THRESHOLD = env.unwrapped.theta_threshold_radians*1.25 #Limit de l'angle del pal
def analyze_results(observations, rewards):
    for step_idx, step in enumerate(observations):
        #Extract positions, angles and actions
        positions = [obs[0][0] for obs in step] #relative position to the target
        angles = [obs[0][2] for obs in step] #pole angles
        actions = [obs[1] for obs in step] #actions

        #Scatter plot
        plt.figure(figsize=(10, 6))
        for pos, angle, action in zip(positions, angles, actions):
            marker = 'x' if action == 1 else 'o'  #X right | O left
            plt.scatter(pos, angle, c='blue', marker=marker, alpha=0.7)

        #Highlight start and end points
        plt.scatter(positions[0], angles[0], c='green', label='Start', s=100) #start piont
        plt.scatter(positions[-1], angles[-1], c='red', label='End', s=100) #end point

        # Customize plot
        plt.xlabel('Position relative to target')
        plt.ylabel('Pole angle (radians)')
        plt.title(f'Distance-Angle Trajectory (Step {step_idx + 1})')
        plt.ylim(-ANGLE_THRESHOLD, ANGLE_THRESHOLD)
        plt.xlim(-X_THRESHOLD, X_THRESHOLD)
        plt.axhline(0, color='gray', linestyle='--', linewidth=0.7)
        plt.axvline(0, color='gray', linestyle='--', linewidth=0.7)
        plt.legend()
        plt.grid(alpha=0.3)
        plt.show()

    #Reward evolution plot
    cumulative_rewards = np.cumsum(rewards) #cumulative reward
    
    #lines
    plt.figure(figsize=(10, 6))
    plt.plot(range(len(rewards)), rewards, marker='o', linestyle='-', color='orange', alpha=0.8, label='Step Reward')
    plt.plot(range(len(cumulative_rewards)), cumulative_rewards, marker='s', linestyle='--', color='blue', alpha=0.8, label='Cumulative Reward')
    #annotations
    plt.text(len(rewards) - 1, rewards[-1] + 0.1, 'Step Reward', color='orange', fontsize=10)
    plt.text(len(cumulative_rewards) - 1, cumulative_rewards[-1] + 0.1, 'Cumulative Reward', color='blue', fontsize=10)
    
    plt.xlabel('Step')
    plt.ylabel('Reward')
    plt.title('Reward Evolution')
    plt.grid(alpha=0.3)
    plt.show()

    #print steps
    print(f'Number of steps taken: {steps}')

# %%
# TODO: passar inputs necessaris
analyze_results(observations, rewards)
# Out:
# Number of steps taken: 18

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>Comentari:</strong>
# <br><br>
#
# #### Distance - Angle plot
#
# Pel fa a la posició respecte a l'objectiu, la trajectòria es manté a prop del x=0. Això indica que el carro s'ha mantingut gairebé centrat en relació amb l'objectiu, suggerint un control estable sobre el moviment del carro. L'angle del pole oscil·la lleugerament per sobre i sota 𝜃 = 0 (posició vertical), però dins d'un rang petit. El sistema manté el pal prop de la vertical durant els passos. Respecte a les accions realitzades (x -> empènyer carro dreta, o -> empènyer carro esquerra), veiem que l'agent alterna entre empentar esquerra i dreta de manera alterna per mantenir l'estabilitat.
#
# #### Reward plot
#
# La recompensa del pas es manté constant en 1 per a tots els passos, cosa que demostra que l'agent manté constantment un entorn estable (ni falla ni es desvia massa). Pel que a la recompensa acumulada, aquesta augmenta linealment amb el nombre de passos, reflectint l'acumulació consistent de recompensa de passos. Això indica que l'episodi avança sense finalitzar, mantenint el sistema de cart-pole equilibrat per a tots els passos observats.
# </div>

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong>Exercici 0.3 (0.5 punts):</strong> Respecte al gràfic realitzat a l'apartat anterior, quina seria la trajectòria que realitzaria un agent que es comportés de manera òptima?
# </div>

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>Comentari:</strong>
# <br><br>
#
# Un agent òptim que mantingués el control perfecte del sistema CartPole hauria de presentar les següents característiques:
#
# 1.**Posició relativa al target (eix x)**:
#     Mantenir la posició del carro molt pròxima a 0, és a dir, el centre del límit de posició.
#
# 2.**Angle del pal (eix y)**:
#     L'angle del pal ha d'estar molt pròxim a 0 radians (completament vertical). Realitzar microajustaments per assegurar que el pal no oscil·li gaire, mantenint l'equilibri de forma contínua.
#
# 3.**Accions**:
#     L'agent òptim ha de realitzar un nombre mínim d'accions per mantenir el sistema estable.
#
# 4.**Punts inicial i final**:
#     Tant el punt inicial com el punt final haurien de ser molt pròxims o idèntics a x=0 i 𝜃=0. La trajectòria òptima mostraria gairebé una línia recta o un punt fix.
#
# </div>

# %% [markdown]
# # 1. Stable baselines 3 (2 pts)

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     Comencem a entrenar un model per solucionar l'entorn. Recordeu que per als apartats 1 i 2 utilitzarem la reward default.
#     Per solucionar l'entorn, utilitzarem el model A2C de la llibreria stable baselines.
# </div>

# %%
from stable_baselines3 import A2C
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import EvalCallback
STEPS = 20_000
EVAL_FREQ = 2000
EVAL_EPISODES = 5

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong>Exercici 1.1 (0.25 punts):</strong> Entrena un model A2C amb paràmetres default i utilitzant una MlpPolicy per entrenar un agent que solucioni el cartpole amb reward default.
#     Afegeix un callback per avaluar el model 5 vegades cada 2 mil iteracions.
#     A més, fes que cada vegada que es trobi un model millor, es guardi el model. Inicialment, abans de començar l'entrenament, utilitza la funció evaluate_policy per avaluar el model sense entrenar. Utilitza també la funció evaluate_policy just abans d'entrenar el model per tenir una idea de com funciona el model abans de ser entrenat.
# </div>

# %% [markdown]
# Opcional: Per a aquells que vulgueu aprofundir una mica més en l'assignatura, també existeix una eina anomenada TensorBoard, molt útil per analitzar el procés d'entrenament de qualsevol xarxa neuronal en general. Stable Baselines 3 té automatitzada la captura de logs amb TensorBoard. Per fer-ho, només cal que passeu al constructor del model el paràmetre tensorboard_log=path on vulgueu guardar el log. Podeu utilitzar aquests logs per veure no només les rewards d'evaluació, sinó també per veure els gradients, la loss i altres paràmetres durant l'entrenament.
#
# Podeu utilitzar-lo en aquest apartat i en tots els que vulgueu durant la pràctica. No puntuïarà ni es tindrà en compte, però permet conèixer més en detall com s'està entrenant el model.

# %%
env = CartPoleEnvRandomTarget(render_mode=None, reward_function = 'default')

#best model save path
model_save_path = "./best_a2c_model"

#carregar callback
#callback = 
callback = EvalCallback(
    env,  # Environment for evaluation
    best_model_save_path=model_save_path,  # Directory to save the best model
    log_path=model_save_path,  # Log directory
    eval_freq=EVAL_FREQ,  # Evaluate the model every EVAL_FREQ steps
    n_eval_episodes=EVAL_EPISODES,  # Number of episodes for each evaluation
    deterministic=True,  # Use deterministic actions for evaluation
    render=False  # Don't render during evaluation
)

#carregar model
model = A2C('MlpPolicy', env, verbose=1)

#avaluació inicial
#initial_eval = 
initial_eval = evaluate_policy(model, env, n_eval_episodes=EVAL_EPISODES, deterministic=True)
print(f"Initial evaluation before training: Mean reward = {initial_eval[0]:.2f}, Std reward = {initial_eval[1]:.2f}")

#TODO: entrenar model
model.learn(total_timesteps=STEPS, callback=callback)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Initial evaluation before training: Mean reward = 8.60, Std reward = 0.49
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20.4     |
# |    ep_rew_mean        | 19.4     |
# | time/                 |          |
# |    fps                | 796      |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.686   |
# |    explained_variance | -0.627   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 2.33     |
# |    value_loss         | 12.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.8     |
# |    ep_rew_mean        | 20.8     |
# | time/                 |          |
# |    fps                | 799      |
# |    iterations         | 200      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.691   |
# |    explained_variance | 0.749    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 2.08     |
# |    value_loss         | 10.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24.2     |
# |    ep_rew_mean        | 23.2     |
# | time/                 |          |
# |    fps                | 800      |
# |    iterations         | 300      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.666   |
# |    explained_variance | 0.0146   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 1.84     |
# |    value_loss         | 8.74     |
# ------------------------------------
# Eval num_timesteps=2000, episode_reward=43.20 +/- 8.08
# Episode length: 44.20 +/- 8.08
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 44.2     |
# |    mean_reward        | 43.2     |
# | time/                 |          |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.472   |
# |    explained_variance | 0.0927   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 1.67     |
# |    value_loss         | 7.16     |
# ------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.3     |
# |    ep_rew_mean     | 25.3     |
# | time/              |          |
# |    fps             | 761      |
# |    iterations      | 400      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2000     |
# ---------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 29.2     |
# |    ep_rew_mean        | 28.2     |
# | time/                 |          |
# |    fps                | 765      |
# |    iterations         | 500      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.658   |
# |    explained_variance | -0.0108  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 1.39     |
# |    value_loss         | 6.07     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 31.4     |
# |    ep_rew_mean        | 30.4     |
# | time/                 |          |
# |    fps                | 763      |
# |    iterations         | 600      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.612   |
# |    explained_variance | 0.0295   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 1        |
# |    value_loss         | 5        |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 34.4     |
# |    ep_rew_mean        | 33.4     |
# | time/                 |          |
# |    fps                | 765      |
# |    iterations         | 700      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.609   |
# |    explained_variance | -0.0324  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.804    |
# |    value_loss         | 4.85     |
# ------------------------------------
# Eval num_timesteps=4000, episode_reward=218.20 +/- 143.23
# Episode length: 219.00 +/- 142.84
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 219      |
# |    mean_reward        | 218      |
# | time/                 |          |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.634   |
# |    explained_variance | -0.00656 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 1.01     |
# |    value_loss         | 4.24     |
# ------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38       |
# |    ep_rew_mean     | 37       |
# | time/              |          |
# |    fps             | 698      |
# |    iterations      | 800      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 4000     |
# ---------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 42.3     |
# |    ep_rew_mean        | 41.3     |
# | time/                 |          |
# |    fps                | 704      |
# |    iterations         | 900      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.421   |
# |    explained_variance | -0.00163 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 1.9      |
# |    value_loss         | 3.72     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 46.5     |
# |    ep_rew_mean        | 45.5     |
# | time/                 |          |
# |    fps                | 709      |
# |    iterations         | 1000     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.531   |
# |    explained_variance | 0.0113   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 1.19     |
# |    value_loss         | 3.21     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.4     |
# |    ep_rew_mean        | 48.4     |
# | time/                 |          |
# |    fps                | 715      |
# |    iterations         | 1100     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.606   |
# |    explained_variance | 0.00141  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.683    |
# |    value_loss         | 2.72     |
# ------------------------------------
# Eval num_timesteps=6000, episode_reward=184.60 +/- 35.77
# Episode length: 185.60 +/- 35.77
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 186      |
# |    mean_reward        | 185      |
# | time/                 |          |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.556   |
# |    explained_variance | -0.00128 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.381    |
# |    value_loss         | 2.3      |
# ------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 54.8     |
# |    ep_rew_mean     | 53.8     |
# | time/              |          |
# |    fps             | 687      |
# |    iterations      | 1200     |
# |    time_elapsed    | 8        |
# |    total_timesteps | 6000     |
# ---------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 58.4      |
# |    ep_rew_mean        | 57.4      |
# | time/                 |           |
# |    fps                | 693       |
# |    iterations         | 1300      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -0.511    |
# |    explained_variance | -0.000445 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 0.776     |
# |    value_loss         | 1.91      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 62.7     |
# |    ep_rew_mean        | 61.7     |
# | time/                 |          |
# |    fps                | 700      |
# |    iterations         | 1400     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.528   |
# |    explained_variance | 0.000234 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.415    |
# |    value_loss         | 1.56     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 65.5     |
# |    ep_rew_mean        | 64.5     |
# | time/                 |          |
# |    fps                | 705      |
# |    iterations         | 1500     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.32    |
# |    explained_variance | 0.000331 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.859    |
# |    value_loss         | 1.23     |
# ------------------------------------
# Eval num_timesteps=8000, episode_reward=500.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 500      |
# |    mean_reward        | 500      |
# | time/                 |          |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.476   |
# |    explained_variance | 0.000255 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.714    |
# |    value_loss         | 0.932    |
# ------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 70.7     |
# |    ep_rew_mean     | 69.7     |
# | time/              |          |
# |    fps             | 651      |
# |    iterations      | 1600     |
# |    time_elapsed    | 12       |
# |    total_timesteps | 8000     |
# ---------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 75.3     |
# |    ep_rew_mean        | 74.3     |
# | time/                 |          |
# |    fps                | 658      |
# |    iterations         | 1700     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.376   |
# |    explained_variance | 1.61e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -3.47    |
# |    value_loss         | 2.21e+03 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 80        |
# |    ep_rew_mean        | 79        |
# | time/                 |           |
# |    fps                | 665       |
# |    iterations         | 1800      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -0.38     |
# |    explained_variance | -0.000645 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | 0.214     |
# |    value_loss         | 0.462     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 83.7     |
# |    ep_rew_mean        | 82.7     |
# | time/                 |          |
# |    fps                | 670      |
# |    iterations         | 1900     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.411   |
# |    explained_variance | 0.000106 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.205    |
# |    value_loss         | 0.292    |
# ------------------------------------
# Eval num_timesteps=10000, episode_reward=223.40 +/- 105.53
# Episode length: 224.40 +/- 105.53
# -------------------------------------
# | eval/                 |           |
# |    mean_ep_length     | 224       |
# |    mean_reward        | 223       |
# | time/                 |           |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.569    |
# |    explained_variance | -7.59e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | 0.156     |
# |    value_loss         | 0.163     |
# -------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 87.6     |
# |    ep_rew_mean     | 86.6     |
# | time/              |          |
# |    fps             | 654      |
# |    iterations      | 2000     |
# |    time_elapsed    | 15       |
# |    total_timesteps | 10000    |
# ---------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 91       |
# |    ep_rew_mean        | 90       |
# | time/                 |          |
# |    fps                | 660      |
# |    iterations         | 2100     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -0.483   |
# |    explained_variance | -0.00104 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 0.175    |
# |    value_loss         | 0.0714   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 96.3     |
# |    ep_rew_mean        | 95.3     |
# | time/                 |          |
# |    fps                | 665      |
# |    iterations         | 2200     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -0.556   |
# |    explained_variance | 0.000208 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 0.0442   |
# |    value_loss         | 0.0153   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 99.3      |
# |    ep_rew_mean        | 98.3      |
# | time/                 |           |
# |    fps                | 670       |
# |    iterations         | 2300      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -0.495    |
# |    explained_variance | -0.000801 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | 0.0052    |
# |    value_loss         | 0.000355  |
# -------------------------------------
# Eval num_timesteps=12000, episode_reward=153.60 +/- 13.25
# Episode length: 154.60 +/- 13.25
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 155      |
# |    mean_reward        | 154      |
# | time/                 |          |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.482   |
# |    explained_variance | 5.35e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.0011   |
# |    value_loss         | 8.65e-06 |
# ------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | 102      |
# | time/              |          |
# |    fps             | 663      |
# |    iterations      | 2400     |
# |    time_elapsed    | 18       |
# |    total_timesteps | 12000    |
# ---------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 107      |
# |    ep_rew_mean        | 106      |
# | time/                 |          |
# |    fps                | 667      |
# |    iterations         | 2500     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.485   |
# |    explained_variance | -0.00614 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.00223  |
# |    value_loss         | 2.54e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 110      |
# |    ep_rew_mean        | 109      |
# | time/                 |          |
# |    fps                | 671      |
# |    iterations         | 2600     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.519   |
# |    explained_variance | 0.00607  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.000549 |
# |    value_loss         | 1.89e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 114      |
# |    ep_rew_mean        | 113      |
# | time/                 |          |
# |    fps                | 674      |
# |    iterations         | 2700     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -0.532   |
# |    explained_variance | -0.0361  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.000438 |
# |    value_loss         | 1.69e-06 |
# ------------------------------------
# Eval num_timesteps=14000, episode_reward=242.20 +/- 86.51
# Episode length: 243.20 +/- 86.51
# -------------------------------------
# | eval/                 |           |
# |    mean_ep_length     | 243       |
# |    mean_reward        | 242       |
# | time/                 |           |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -0.473    |
# |    explained_variance | -0.000135 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | 0.00129   |
# |    value_loss         | 7.41e-06  |
# -------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 117      |
# |    ep_rew_mean     | 116      |
# | time/              |          |
# |    fps             | 662      |
# |    iterations      | 2800     |
# |    time_elapsed    | 21       |
# |    total_timesteps | 14000    |
# ---------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 120      |
# |    ep_rew_mean        | 119      |
# | time/                 |          |
# |    fps                | 666      |
# |    iterations         | 2900     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.574   |
# |    explained_variance | -0.24    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.000409 |
# |    value_loss         | 8.81e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 123      |
# |    ep_rew_mean        | 122      |
# | time/                 |          |
# |    fps                | 670      |
# |    iterations         | 3000     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.525   |
# |    explained_variance | -0.00356 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.00123  |
# |    value_loss         | 1.82e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 128      |
# |    ep_rew_mean        | 127      |
# | time/                 |          |
# |    fps                | 673      |
# |    iterations         | 3100     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.528   |
# |    explained_variance | -0.00353 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.00191  |
# |    value_loss         | 1.96e-05 |
# ------------------------------------
# Eval num_timesteps=16000, episode_reward=172.00 +/- 167.05
# Episode length: 172.80 +/- 166.66
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 173      |
# |    mean_reward        | 172      |
# | time/                 |          |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.458   |
# |    explained_variance | 0.0278   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.000847 |
# |    value_loss         | 5.35e-06 |
# ------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 131      |
# |    ep_rew_mean     | 130      |
# | time/              |          |
# |    fps             | 664      |
# |    iterations      | 3200     |
# |    time_elapsed    | 24       |
# |    total_timesteps | 16000    |
# ---------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 133      |
# |    ep_rew_mean        | 132      |
# | time/                 |          |
# |    fps                | 667      |
# |    iterations         | 3300     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.356   |
# |    explained_variance | -0.278   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.000943 |
# |    value_loss         | 1.65e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 137      |
# |    ep_rew_mean        | 136      |
# | time/                 |          |
# |    fps                | 670      |
# |    iterations         | 3400     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.417   |
# |    explained_variance | -0.0304  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.00125  |
# |    value_loss         | 5.12e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 138      |
# |    ep_rew_mean        | 137      |
# | time/                 |          |
# |    fps                | 673      |
# |    iterations         | 3500     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.471   |
# |    explained_variance | -0.00135 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.00135  |
# |    value_loss         | 5.74e-05 |
# ------------------------------------
# Eval num_timesteps=18000, episode_reward=163.00 +/- 9.06
# Episode length: 164.00 +/- 9.06
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 164      |
# |    mean_reward        | 163      |
# | time/                 |          |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.552   |
# |    explained_variance | -12.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.000243 |
# |    value_loss         | 2.8e-06  |
# ------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 141      |
# |    ep_rew_mean     | 140      |
# | time/              |          |
# |    fps             | 667      |
# |    iterations      | 3600     |
# |    time_elapsed    | 26       |
# |    total_timesteps | 18000    |
# ---------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 142      |
# |    ep_rew_mean        | 141      |
# | time/                 |          |
# |    fps                | 670      |
# |    iterations         | 3700     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.45    |
# |    explained_variance | -0.0147  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.00101  |
# |    value_loss         | 2.23e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 138      |
# |    ep_rew_mean        | 137      |
# | time/                 |          |
# |    fps                | 672      |
# |    iterations         | 3800     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.403   |
# |    explained_variance | 0.0122   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.00519  |
# |    value_loss         | 8.96e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 133      |
# |    ep_rew_mean        | 132      |
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 3900     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -0.438   |
# |    explained_variance | -0.503   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.0011   |
# |    value_loss         | 5.65e-06 |
# ------------------------------------
# Eval num_timesteps=20000, episode_reward=93.60 +/- 15.51
# Episode length: 94.60 +/- 15.51
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 94.6     |
# |    mean_reward        | 93.6     |
# | time/                 |          |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.482   |
# |    explained_variance | -3.12    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.00139  |
# |    value_loss         | 2.82e-05 |
# ------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 131      |
# |    ep_rew_mean     | 130      |
# | time/              |          |
# |    fps             | 673      |
# |    iterations      | 4000     |
# |    time_elapsed    | 29       |
# |    total_timesteps | 20000    |
# ---------------------------------

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong>Exercici 1.2 (0.25 punts):</strong> Carrega el millor model trobat i executa la funció evaluate_policy. Compara les rewards inicials i finals.
#     Executa un episodi i analitza els resultats utilitzant la funció prèviament creada per visualitzar el comportament de l'agent en l'espai d'angle-posició.
# </div>

# %%
import os
#best model path
best_model_path = "./best_a2c_model/best_model.zip"

#carregar el millor model
if os.path.exists(best_model_path):
    model = A2C.load(best_model_path)
    print("El millor model ha estat carregat correctament.")
else:
    raise FileNotFoundError(f"No s'ha trobat el model a {best_model_path}")

#avaluació final
final_eval = final_eval = evaluate_policy(model, env, n_eval_episodes=EVAL_EPISODES, deterministic=True)
print (f'Initial evaluation: {initial_eval}')
print (f'Best model evaluation: {final_eval}')
print(f"Recompensa final mitjana: {final_eval[0]:.2f} +/- {final_eval[1]:.2f}")
# Out:
# El millor model ha estat carregat correctament.
# Initial evaluation: (8.6, 0.48989794855663565)
# Best model evaluation: (500.0, 0.0)
# Recompensa final mitjana: 500.00 +/- 0.00

# %%
#TODO: Completar funcio d'avaluació del model entrenat
def evaluate_trained_model(env,model):
    #Primer executem un cop l'entorn
    obs,_ = env.reset()
    done = False
    
    #Init variables
    observations = []
    rewards = []
    step = []

    while not done:
        # TODO: Escollir accio en base al model
        action, _ = model.predict(obs, deterministic=True)

        # TODO: Executar accio i esperar resposta de l'entorn
        next_obs, reward, terminated, truncated, _ = env.step(action)

        # TODO: Guardar informacio necesaria per a poder fer les grafiques despres
        step.append((obs, action))
        rewards.append(reward)
        
        #update state and check end
        obs = next_obs
        done = terminated or truncated
        
    observations.append(step)

    #Analitzem resultats
    analyze_results(observations,rewards)
    print(f"Total Reward: {sum(rewards)}")

# %%
env = CartPoleEnvRandomTarget(render_mode='human',reward_function = 'default') #podeis hacer render mode = None
evaluate_trained_model(env,model)

env.close()
# Out:
# Number of steps taken: 18
# Total Reward: 500

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>Comentari:</strong>
# <br><br>
#
# #### Distance - Angle plot
# La trajectòria mostra que el pal s'ha mogut amb una oscil·lació reduïda al voltant del centre (target), mantenint l'angle sota control durant tot el temps. L'agent ha sigut capaç de mantenir el balanç i controlar la posició del carro. Tot i això, les oscil·lacions són visibles i indiquen que l'agent ho ha trobat una trajectòria òptima completament estable.
#
# #### Reward plot
#
# La recompensa acumulativa mostra una línia amb una pujada constant, suggerint que l'agent acumula punts a cada pas sense fallar durant els episodis.
#
#
#
#
# Com a conclusions finals podem dir que l'agent ha tingut un control efectiu amb algunes oscil·lacions en la trajectòria de posició i angle que mostren que hi ha marge de millora, però amb un bon rendiment general.
# </div>

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong>Exercici 1.3 (0.5 punts):</strong> Un dels problemes que tenim amb aquest entorn és que estem avaluant el model sobre un entorn random. Això genera que durant el callback puguem guardar un model no perquè sigui millor que els anteriors, sinó perquè els entorns sobre els quals s'ha avaluat són més senzills. Per exemple, si en un dels callbacks el target es situa als extrems, tot i que l'agent es comporti millor que les seves versions anteriors, potser no ho sabrem perquè la reward total serà més petita que, per exemple, una versió amb un comportament pitjor, però en què el target s'ha situat al centre.
#     Modifica l'entorn de cartpole (veure TODOS dins del codi) perquè en avaluació el target es trobi en 9 posicions diferents:
#     <ul>
#     <li> Als extrems</li>
#     <li> A 3/4, 1/2 i 1/4 de la distància entre el centre i els extrems</li>
#     <li> Just al centre</li>
#     </ul>
#     Setejarem a partir d'ara el número d'episodis d'avaluació a 18 (EVAL_EPISODES) perquè s'executi 2 vegades cada casuística.
# </div>

# %%
"""
Classic cart-pole system implemented by Rich Sutton et al.
Copied from http://incompleteideas.net/sutton/book/code/pole.c
permalink: https://perma.cc/C9ZM-652R
"""

import math
from typing import Optional, Union

import numpy as np

import gymnasium as gym
from gymnasium import spaces
from gymnasium.envs.classic_control import utils
from gymnasium.error import DependencyNotInstalled



class CartPoleEnvRandomTarget(gym.Env[np.ndarray, Union[int, np.ndarray]]):
    """
    ## Description

    This environment corresponds to a modification of the version of the cart-pole problem described by Barto, Sutton, and Anderson in
    ["Neuronlike Adaptive Elements That Can Solve Difficult Learning Control Problem"](https://ieeexplore.ieee.org/document/6313077).
    A pole is attached by an un-actuated joint to a cart, which moves along a frictionless track.
    The pendulum is placed upright on the cart and the goal is to balance the pole by applying forces
     in the left and right direction on the cart.
     The modification consists on a target appearing into scene. The cart must be as close to the target as posible

    For more details about original cartpole look for source code in gymnasium.
    """


    metadata = {
        "render_modes": ["human", "rgb_array"],
        "render_fps": 50,
    }

    def __init__(
        self,
        target_desire_factor: float = 0.5,
        reward_function: str = "default",
        is_eval=False,
        increased_actions=False,
        render_mode: Optional[str] = None,
    ):

        self.gravity = 9.8
        self.masscart = 1.0
        self.masspole = 0.1
        self.total_mass = self.masspole + self.masscart
        self.length = 0.5  # actually half the pole's length
        self.polemass_length = self.masspole * self.length
        self.force_mag = 10.0
        self.tau = 0.02  # seconds between state updates

        self.max_steps = 500
        self.steps = 0

        # Angle at which to fail the episode
        self.theta_threshold_radians = 12 * 2 * math.pi / 360
        self.x_threshold = 2.4
        self.target_threshold = 2

        high = np.array(
            [
                self.x_threshold * 2,
                np.inf,
                self.theta_threshold_radians * 2,
                np.inf,
                self.target_threshold * 2,
            ],
            dtype=np.float32,
        )
        self.increased_actions = increased_actions
        if self.increased_actions:
            #TODO 3.1: Ampliar l'espai d'observacions
            raise NotImplementedError("Increased actions should be implemented")
        else:
            self.action_space = spaces.Discrete(2)
        self.observation_space = spaces.Box(-high, high, dtype=np.float32)

        self.render_mode = render_mode

        self.screen_width = 600
        self.screen_height = 400
        self.screen = None
        self.clock = None
        self.isopen = True
        self.state: np.ndarray | None = None

        self.steps_beyond_terminated = None

        #TODO 1.3: Tenir en compte si l'entorn és d'avaluació
        self.is_eval = is_eval
        self.target_position_index = None #index to control target position
        self.target_position = self.generate_random_target_position()

        self.target_desire_factor = min(
            max(target_desire_factor, 0), 1
        )  # between 0 and 1
        if reward_function in ["default", "custom"]:
            self.reward_function = reward_function
        else:
            raise AttributeError("reward function must be either default or custom")

    def generate_random_target_position(
        self,
    ):
        if self.is_eval:
            #TODO 1.3:Tingueu en compte si l'entorn és d'avaluació per situar el target en unes posicions concretes.
            #preset target positions for evaluation mode
            eval_positions = [
                -self.x_threshold,                      # Extrem esquerre
                -self.x_threshold * 0.75,               # 3/4 esquerre
                -self.x_threshold * 0.5,                # 1/2 esquerre
                -self.x_threshold * 0.25,               # 1/4 esquerre
                0.0,                                    # Centre
                self.x_threshold * 0.25,                # 1/4 dret
                self.x_threshold * 0.5,                 # 1/2 dret
                self.x_threshold * 0.75,                # 3/4 dret
                self.x_threshold                        # Extrem dret
            ]
            #select a random position (first execution)
            if self.target_position_index is None:
                self.target_position_index = np.random.randint(0,9)

            #select the target position based on the index
            target_position = eval_positions[self.target_position_index]

            #update the index
            self.target_position_index = (self.target_position_index + 1) % 9
            
            return target_position
        else:
            return np.random.uniform(-self.x_threshold, self.x_threshold)

    def custom_reward(self, target_position, current_position, angle, terminated):
        if self.reward_function == "default":
            #Reward default del cartpole
            return 1 if not terminated else 0
        else:
            angle_reward = (
                -abs(angle) / (2.0 * self.x_threshold) / self.theta_threshold_radians
            )
            target_reward = -(abs(target_position - current_position) ** 2) / (
                (2 * self.x_threshold) ** 2
            )
            return (
                1
                + self.target_desire_factor * target_reward
                + (1 - self.target_desire_factor) * angle_reward
            )
        #TODO 2.2: Implementar 2 funcions de reward extra

    def step(self, action):
        assert self.action_space.contains(
            action
        ), f"{action!r} ({type(action)}) invalid"
        assert self.state is not None, "Call reset before using step method."
        x, x_dot, theta, theta_dot, _ = self.state
        if self.increased_actions:
            force_factor = action - 3
            force = (
                force_factor / 3 * self.force_mag
                if force_factor > 0
                else (force_factor - 1) / 3 * self.force_mag
            )
        else:
            force = self.force_mag if action == 1 else -self.force_mag
        costheta = np.cos(theta)
        sintheta = np.sin(theta)

        # For the interested reader:
        # https://coneural.org/florian/papers/05_cart_pole.pdf
        temp = (
            force + self.polemass_length * np.square(theta_dot) * sintheta
        ) / self.total_mass
        thetaacc = (self.gravity * sintheta - costheta * temp) / (
            self.length
            * (4.0 / 3.0 - self.masspole * np.square(costheta) / self.total_mass)
        )
        xacc = temp - self.polemass_length * thetaacc * costheta / self.total_mass

        x = x + self.tau * x_dot
        x_dot = x_dot + self.tau * xacc
        theta = theta + self.tau * theta_dot
        theta_dot = theta_dot + self.tau * thetaacc

        self.state = np.array(
            (x, x_dot, theta, theta_dot, self.target_position), dtype=np.float64
        ) #Aquest estat es diferent respecte al del cartpole original

        terminated = bool(
            x < -self.x_threshold
            or x > self.x_threshold
            or theta < -self.theta_threshold_radians
            or theta > self.theta_threshold_radians
        )

        reward = self.custom_reward(self.target_position, x, theta, terminated)

        if self.render_mode == "human":
            self.render()

        # truncation=False as the time limit is handled by the `TimeLimit` wrapper added during `make`
        self.steps += 1
        if self.steps >= self.max_steps:
            truncated = True
        else:
            truncated = False
        return np.array(self.state, dtype=np.float32), reward, terminated, truncated, {}

    def reset(
        self,
        *,
        seed: Optional[int] = None,
        options: Optional[dict] = None,
    ):

        super().reset(seed=seed)
        self.steps = 0
        # Note that if you use custom reset bounds, it may lead to out-of-bound
        # state/observations.
        low, high = utils.maybe_parse_reset_bounds(
            options, -0.05, 0.05  # default low
        )  # default high

        self.state = self.np_random.uniform(low=low, high=high, size=(4,)).tolist()
        self.steps_beyond_terminated = None

        #Generar posició aleatòria del target i guardar en l'estat
        self.target_position = self.generate_random_target_position()
        self.state.append(self.target_position)

        self.state = np.array(self.state)
        if self.render_mode == "human":
            self.render()
        return np.array(self.state, dtype=np.float32), {}

    def render(self):
        if self.render_mode is None:
            assert self.spec is not None
            gym.logger.warn(
                "You are calling render method without specifying any render mode. "
                "You can specify the render_mode at initialization, "
                f'e.g. gym.make("{self.spec.id}", render_mode="rgb_array")'
            )
            return

        try:
            import pygame
            from pygame import gfxdraw
        except ImportError as e:
            raise DependencyNotInstalled(
                'pygame is not installed, run `pip install "gymnasium[classic-control]"`'
            ) from e

        if self.screen is None:
            pygame.init()
            if self.render_mode == "human":
                pygame.display.init()
                self.screen = pygame.display.set_mode(
                    (self.screen_width, self.screen_height)
                )
            else:  # mode == "rgb_array"
                self.screen = pygame.Surface((self.screen_width, self.screen_height))
        if self.clock is None:
            self.clock = pygame.time.Clock()

        world_width = self.x_threshold * 2
        scale = self.screen_width / world_width
        polewidth = 10.0
        polelen = scale * (2 * self.length)
        cartwidth = 50.0
        cartheight = 30.0
        targetwidth = 10
        targetheight = 10

        if self.state is None:
            return None

        x = self.state

        self.surf = pygame.Surface((self.screen_width, self.screen_height))
        self.surf.fill((255, 255, 255))

        l, r, t, b = -cartwidth / 2, cartwidth / 2, cartheight / 2, -cartheight / 2
        axleoffset = cartheight / 4.0
        cartx = x[0] * scale + self.screen_width / 2.0  # MIDDLE OF CART
        carty = 100  # TOP OF CART
        cart_coords = [(l, b), (l, t), (r, t), (r, b)]
        cart_coords = [(c[0] + cartx, c[1] + carty) for c in cart_coords]
        gfxdraw.aapolygon(self.surf, cart_coords, (0, 0, 0))
        gfxdraw.filled_polygon(self.surf, cart_coords, (0, 0, 0))

        l, r, t, b = (
            -polewidth / 2,
            polewidth / 2,
            polelen - polewidth / 2,
            -polewidth / 2,
        )

        pole_coords = []
        for coord in [(l, b), (l, t), (r, t), (r, b)]:
            coord = pygame.math.Vector2(coord).rotate_rad(-x[2])
            coord = (coord[0] + cartx, coord[1] + carty + axleoffset)
            pole_coords.append(coord)
        gfxdraw.aapolygon(self.surf, pole_coords, (202, 152, 101))
        gfxdraw.filled_polygon(self.surf, pole_coords, (202, 152, 101))

        gfxdraw.aacircle(
            self.surf,
            int(cartx),
            int(carty + axleoffset),
            int(polewidth / 2),
            (129, 132, 203),
        )
        gfxdraw.filled_circle(
            self.surf,
            int(cartx),
            int(carty + axleoffset),
            int(polewidth / 2),
            (129, 132, 203),
        )

        l, r, t, b = (
            -targetwidth / 2,
            targetwidth / 2,
            targetheight / 2,
            -targetheight / 2,
        )
        axleoffset = targetheight / 4.0
        targetx = x[-1] * scale + self.screen_width / 2.0  # MIDDLE OF target
        targety = 90  # TOP OF target
        target_coords = [(l, b), (l, t), (r, t), (r, b)]
        target_coords = [(c[0] + targetx, c[1] + targety) for c in target_coords]
        gfxdraw.aapolygon(self.surf, target_coords, (10, 255, 10))
        gfxdraw.filled_polygon(self.surf, target_coords, (10, 255, 10))

        gfxdraw.hline(self.surf, 0, self.screen_width, carty, (0, 0, 0))

        self.surf = pygame.transform.flip(self.surf, False, True)
        self.screen.blit(self.surf, (0, 0))
        if self.render_mode == "human":
            pygame.event.pump()
            self.clock.tick(self.metadata["render_fps"])
            pygame.display.flip()

        elif self.render_mode == "rgb_array":
            return np.transpose(
                np.array(pygame.surfarray.pixels3d(self.screen)), axes=(1, 0, 2)
            )

    def close(self):
        if self.screen is not None:
            import pygame

            pygame.display.quit()
            pygame.quit()
            self.isopen = False

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong>Exercici 1.4.1 (0.5 punts):</strong> Modifica la funció analyze_results perquè creï els mateixos gràfics que es generaven abans però per a cada casuística. Suposa que a la funció li arribaran 9 episodis diferents, 1 per a cada casuística. Podeu utilitzar subplots de matplotlib. Us hauria de quedar alguna cosa així:
# </div>

# %% [markdown]
# ![image-3.png](exemple_sortida.png)

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong>Exercici 1.4.2 (0.5 punts):</strong> Repeteix els exercicis 1.1 i 1.2 però avaluant amb un entorn d'avaluació i utilitzant la nova funció d'avaluació. Recorda que tot i que els EVAL_EPISODES són 18, per avaluar l'agent i fer els gràfics executarem 1 vegada cada casuística, fent un total de 9 execucions.
# </div>

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.env_util import DummyVecEnv

#Modificar primer els TODOS de l'entorn
EVAL_EPISODES = 18
STEPS = 20000
EVAL_FREQ = 2000
env = CartPoleEnvRandomTarget(render_mode=None,reward_function = 'default')
eval_env = CartPoleEnvRandomTarget(render_mode=None,reward_function = 'default',is_eval = True)

#TODO: Completar codi
#Creem callback i model. Per al callback farem servir l'entorn d'evaluacio, per al model el normal
callback = EvalCallback(
    eval_env=DummyVecEnv([lambda: eval_env]),  # Vectoritzar l'entorn d'avaluació
    best_model_save_path="./best_model/",
    log_path="./logs/",
    eval_freq=EVAL_FREQ,  # Freqüència d'avaluació
    n_eval_episodes=EVAL_EPISODES,  # Episodis d'avaluació
    deterministic=True,
    render=False
)

model = PPO(
    "MlpPolicy",  # Política basada en xarxes neuronals
    env,
    verbose=1,
    tensorboard_log="./tensorboard/"
)

#Executem evaluacio inicial
initial_eval = evaluate_policy(
    model,
    DummyVecEnv([lambda: eval_env]),
    n_eval_episodes=9,  # Un episodi per a cada casuística
    return_episode_rewards=True  # Retornar els resultats per episodi
)
print(f"Initial evaluation: {initial_eval}")

#Entrenem model
model.learn(total_timesteps=STEPS, callback=callback)

#Carreguem millor model i executem validació final
best_model_path = "./best_model/best_model.zip"
if os.path.exists(best_model_path):
    model = PPO.load(best_model_path)
    print("El millor model ha estat carregat correctament.")
else:
    raise FileNotFoundError(f"No s'ha trobat el model a {best_model_path}")

final_eval = evaluate_policy(
    model,
    DummyVecEnv([lambda: eval_env]),
    n_eval_episodes=9,  # Un episodi per a cada casuística
    return_episode_rewards=True
)
# print (f'Initial evaluation: {initial_eval}')
print (f'Best model evaluation: {final_eval}')
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Initial evaluation: ([9.0, 8.0, 9.0, 9.0, 9.0, 8.0, 9.0, 8.0, 8.0], [10, 9, 10, 10, 10, 9, 10, 9, 9])
# Logging to ./tensorboard/PPO_15
# Eval num_timesteps=2000, episode_reward=8.44 +/- 0.68
# Episode length: 9.44 +/- 0.68
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 9.44     |
# |    mean_reward     | 8.44     |
# | time/              |          |
# |    total_timesteps | 2000     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.8     |
# |    ep_rew_mean     | 20.8     |
# | time/              |          |
# |    fps             | 1536     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Eval num_timesteps=4000, episode_reward=161.17 +/- 111.54
# Episode length: 162.17 +/- 111.54
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 162          |
# |    mean_reward          | 161          |
# | time/                   |              |
# |    total_timesteps      | 4000         |
# | train/                  |              |
# |    approx_kl            | 0.0076465383 |
# |    clip_fraction        | 0.0975       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | 0.0328       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.75         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.014       |
# |    value_loss           | 54.1         |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.1     |
# |    ep_rew_mean     | 24.1     |
# | time/              |          |
# |    fps             | 848      |
# |    iterations      | 2        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Eval num_timesteps=6000, episode_reward=148.06 +/- 97.48
# Episode length: 149.00 +/- 97.27
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 149         |
# |    mean_reward          | 148         |
# | time/                   |             |
# |    total_timesteps      | 6000        |
# | train/                  |             |
# |    approx_kl            | 0.009142838 |
# |    clip_fraction        | 0.0734      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.0471      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 36.5        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.2     |
# |    ep_rew_mean     | 33.2     |
# | time/              |          |
# |    fps             | 744      |
# |    iterations      | 3        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 6144     |
# ---------------------------------
# Eval num_timesteps=8000, episode_reward=346.44 +/- 167.11
# Episode length: 347.00 +/- 166.70
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 347         |
# |    mean_reward          | 346         |
# | time/                   |             |
# |    total_timesteps      | 8000        |
# | train/                  |             |
# |    approx_kl            | 0.008512726 |
# |    clip_fraction        | 0.0916      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.636      |
# |    explained_variance   | 0.201       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 51.5        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.9     |
# |    ep_rew_mean     | 45.9     |
# | time/              |          |
# |    fps             | 625      |
# |    iterations      | 4        |
# |    time_elapsed    | 13       |
# |    total_timesteps | 8192     |
# ---------------------------------
# Eval num_timesteps=10000, episode_reward=277.00 +/- 179.13
# Episode length: 277.61 +/- 178.64
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 278          |
# |    mean_reward          | 277          |
# | time/                   |              |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0053246003 |
# |    clip_fraction        | 0.0426       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.619       |
# |    explained_variance   | 0.217        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.7         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.01        |
# |    value_loss           | 67           |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 61.5     |
# |    ep_rew_mean     | 60.5     |
# | time/              |          |
# |    fps             | 585      |
# |    iterations      | 5        |
# |    time_elapsed    | 17       |
# |    total_timesteps | 10240    |
# ---------------------------------
# Eval num_timesteps=12000, episode_reward=386.44 +/- 118.34
# Episode length: 387.00 +/- 117.91
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 387        |
# |    mean_reward          | 386        |
# | time/                   |            |
# |    total_timesteps      | 12000      |
# | train/                  |            |
# |    approx_kl            | 0.00706329 |
# |    clip_fraction        | 0.0803     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.607     |
# |    explained_variance   | 0.493      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 17.3       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0137    |
# |    value_loss           | 61.2       |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 77.2     |
# |    ep_rew_mean     | 76.2     |
# | time/              |          |
# |    fps             | 540      |
# |    iterations      | 6        |
# |    time_elapsed    | 22       |
# |    total_timesteps | 12288    |
# ---------------------------------
# Eval num_timesteps=14000, episode_reward=441.94 +/- 88.21
# Episode length: 442.39 +/- 87.85
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 442         |
# |    mean_reward          | 442         |
# | time/                   |             |
# |    total_timesteps      | 14000       |
# | train/                  |             |
# |    approx_kl            | 0.008304913 |
# |    clip_fraction        | 0.0852      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.582      |
# |    explained_variance   | 0.343       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.6        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 75.1        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 92.1     |
# |    ep_rew_mean     | 91.1     |
# | time/              |          |
# |    fps             | 509      |
# |    iterations      | 7        |
# |    time_elapsed    | 28       |
# |    total_timesteps | 14336    |
# ---------------------------------
# Eval num_timesteps=16000, episode_reward=357.72 +/- 120.10
# Episode length: 358.39 +/- 119.71
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 358        |
# |    mean_reward          | 358        |
# | time/                   |            |
# |    total_timesteps      | 16000      |
# | train/                  |            |
# |    approx_kl            | 0.00797132 |
# |    clip_fraction        | 0.0482     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.563     |
# |    explained_variance   | 0.471      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 17.5       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00915   |
# |    value_loss           | 60.1       |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 107      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    fps             | 496      |
# |    iterations      | 8        |
# |    time_elapsed    | 33       |
# |    total_timesteps | 16384    |
# ---------------------------------
# Eval num_timesteps=18000, episode_reward=285.33 +/- 100.15
# Episode length: 286.22 +/- 99.91
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 286          |
# |    mean_reward          | 285          |
# | time/                   |              |
# |    total_timesteps      | 18000        |
# | train/                  |              |
# |    approx_kl            | 0.0043039303 |
# |    clip_fraction        | 0.0194       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.584       |
# |    explained_variance   | 0.716        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.71         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00279     |
# |    value_loss           | 29.6         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 127      |
# |    ep_rew_mean     | 126      |
# | time/              |          |
# |    fps             | 493      |
# |    iterations      | 9        |
# |    time_elapsed    | 37       |
# |    total_timesteps | 18432    |
# ---------------------------------
# Eval num_timesteps=20000, episode_reward=409.50 +/- 66.22
# Episode length: 410.33 +/- 65.99
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 410         |
# |    mean_reward          | 410         |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.007627958 |
# |    clip_fraction        | 0.081       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.578      |
# |    explained_variance   | 0.755       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.72        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 34.7        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 143      |
# |    ep_rew_mean     | 142      |
# | time/              |          |
# |    fps             | 480      |
# |    iterations      | 10       |
# |    time_elapsed    | 42       |
# |    total_timesteps | 20480    |
# ---------------------------------
# El millor model ha estat carregat correctament.
# Best model evaluation: ([500.0, 500.0, 415.0, 296.0, 500.0, 385.0, 500.0, 250.0, 500.0], [500, 500, 416, 297, 500, 386, 500, 251, 500])

# %%
def analyze_results(observations, rewards):
    """
    Genera subplots per cada casuística:
    - Gràfiques de trajectòries "distància-angle"
    - Gràfiques de recompenses per cada pas
    """
    n_cases = len(observations)
    fig, axes = plt.subplots(3, 5, figsize=(20, 12))  # Subplots de 3 files i 5 columnes
    axes = axes.flatten()  # Aplanem per facilitar l'iteració

    for case_idx in range(n_cases):
        obs_case = observations[case_idx]
        rewards_case = rewards[case_idx]

        # Dades d'observacions i accions
        positions = [obs[0][0] for obs in obs_case]  # Posicions relatives al target
        angles = [obs[0][2] for obs in obs_case]  # Angles del pal
        actions = [obs[1] for obs in obs_case]  # Accions

        # Gràfic de trajectòria posició-angle
        ax = axes[case_idx]
        ax.plot(positions, angles, label="Trajectòria", color='blue', alpha=0.8)
        ax.scatter(positions[0], angles[0], label="Inicial", color='green', s=50)
        ax.scatter(positions[-1], angles[-1], label="Final", color='red', s=50)

        ax.set_title(f"Casuística {case_idx + 1} (Recompensa acumulada: {sum(rewards_case)})")
        ax.set_xlabel("Distància al target")
        ax.set_ylabel("Angle del pal (rad)")
        ax.legend()
        ax.grid(alpha=0.3)

    # Omplir subplots sobrants (si n_cases < 15)
    for empty_ax in axes[n_cases:]:
        empty_ax.axis('off')

    plt.tight_layout()
    plt.show()

    # Gràfiques de recompenses per pas
    fig, reward_axes = plt.subplots(3, 5, figsize=(20, 12))
    reward_axes = reward_axes.flatten()

    for case_idx in range(n_cases):
        rewards_case = rewards[case_idx]

        # Gràfic de recompenses per pas
        reward_ax = reward_axes[case_idx]
        reward_ax.plot(range(len(rewards_case)), rewards_case, label="Recompenses per pas", color='blue')
        reward_ax.set_title(f"Casuística {case_idx + 1} (Recompensa acumulada: {sum(rewards_case)})")
        reward_ax.set_xlabel("Step")
        reward_ax.set_ylabel("Recompensa")
        reward_ax.grid(alpha=0.3)

    # Omplir subplots sobrants (si n_cases < 15)
    for empty_ax in reward_axes[n_cases:]:
        empty_ax.axis('off')

    plt.tight_layout()
    plt.show()

# %%
from tqdm import tqdm

def evaluate_trained_model(env, model):
    """
    Avaluem un model entrenat per 9 casuístiques i generem gràfiques.
    """
    n_eval_cases = 9
    observations = []  # Guardar les observacions (trajectòries)
    rewards = []  # Guardar les recompenses per cada casuística

    # Executem una iteració per casuística
    for _ in tqdm(range(n_eval_cases), desc="Avaluant casuístiques"):
        done = False
        episode_obs = []
        episode_rewards = []

        obs, _ = env.reset()
        while not done:
            action, _states = model.predict(obs, deterministic=True)  # Acció del model entrenat
            next_obs, reward, done, _, _ = env.step(action)  # Pas de simulació

            # Guardem observacions, accions i recompenses
            episode_obs.append((obs, action))
            episode_rewards.append(reward)
            obs = next_obs

        # Guardem trajectòria i recompenses d'aquest cas
        observations.append(episode_obs)
        rewards.append(episode_rewards)

    # Generem gràfiques amb la funció `analyze_results`
    analyze_results(observations, rewards)

# %%
#Executem la funcio
eval_env = CartPoleEnvRandomTarget(render_mode='human',reward_function = 'default',is_eval = True) #podeis modificar el render mode a None
eval_env = CartPoleEnvRandomTarget(render_mode='None',reward_function = 'default',is_eval = True)
evaluate_trained_model(eval_env,model)

eval_env.close()
# Out:
# Avaluant casuístiques: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:02<00:00,  3.75it/s]

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>Comentari:</strong>
# <br><br>
#
# #### Distance - Angle plot
# Les trajectòries de les diferents gràfiques mostren de forma recorrent un patró on les oscil·lacions al inici són molt reduides i suaus, i que seguidament, començen a apareixer moviments un pel més bruscos (més llargs). Aquests en part sembla que aturen la intensitat, però són l'inici de la perdua del control i posterior finalització de l'episodi.
#
# #### Reward plot
#
# El reward en cada un dels gràfics de recompensa sembla indicar que la finalització de l'episodi és causat per un factor trucated. Ho podem deduir donat que en tots ells tenim un punt on la recompensa passa a tenir un valor de 0 i l'episodi no continua.
# </div>

# %% [markdown]
# # 2. Efecte del reward (3 pts)

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong>Exercici 2.1 (1.25 punts):</strong> Entrena un agent utilitzant diferents valors del paràmetre target_desire_factor:
#     <ul>
#         <li>target_desire_factor=0</li>
#         <li>target_desire_factor=0.5</li>
#         <li>target_desire_factor=1</li>
#     </ul>
#
# Executa un episodi amb el millor agent (recorda utilitzar els callbacks) i comenta els resultats obtinguts.
# </div>

# %%
#TODO: Repetir el mateix que en els exercicis anteriors. Callback, model, avaluació inicial, càrrega del millor model i entrenament.
#Al final, analitzar els resultats utilitzant la funció evaluate_trained_model.
#Repetir per a cada valor de target_desire_factor.

target_desire_factors = [0, 0.5, 1]
STEPS = 20000
EVAL_FREQ = 2000

# Funció per entrenar l'agent per un valor de target_desire_factor
def train_agent(target_desire_factor):
    # Creem l'entorn d'entrenament i avaluació amb el valor actual de target_desire_factor
    env = CartPoleEnvRandomTarget(render_mode=None, reward_function='custom', target_desire_factor=target_desire_factor)
    eval_env = CartPoleEnvRandomTarget(render_mode=None, reward_function='custom', target_desire_factor=target_desire_factor, is_eval=True)

    # Modl
    model = PPO("MlpPolicy", env, verbose=1)
    
    # Avaluació inicial abans de l'entrenament
    print(f"Evaluació inicial per target_desire_factor = {target_desire_factor}:")
    initial_eval = evaluate_trained_model(model, eval_env)  # Avaluem el model sense entrenar
    print(f"Initial evaluation: {initial_eval}")

    # Iniciem l'entrenament
    print(f"Iniciant l'entrenament per target_desire_factor = {target_desire_factor}...")
    
    # Callback per a l'avaluació durant l'entrenament
    eval_callback = EvalCallback(
        DummyVecEnv([lambda: eval_env]),  # Creem l'entorn vectoritzat dins del callback
        best_model_save_path=f"./best_model_{target_desire_factor}", 
        log_path=f"./logs_{target_desire_factor}", 
        eval_freq=EVAL_FREQ,
        verbose=1
    )

    # Entrenem el model
    model.learn(total_timesteps=STEPS, callback=eval_callback)

    # Carreguem el millor model
    model = PPO.load(f"./best_model_{target_desire_factor}/best_model.zip")
    
    return model, eval_env
    
# Funció per avaluar el model entrenat
def evaluate_trained_model(model, eval_env):
    total_reward = 0
    total_steps = 0
    for _ in range(10):  # Evaluem durant 10 episodis
        obs, _ = eval_env.reset()  # Ens assegurem d'obeir només l'observació
        done = False
        episode_reward = 0
        steps = 0
        while not done:
            action, _ = model.predict(obs)
            result = eval_env.step(action)
            # Desempaquetem els primers 4 elements
            obs, reward, done, _ = result[:4]
            episode_reward += reward
            steps += 1
        total_reward += episode_reward
        total_steps += steps
    
    average_reward = total_reward / 10
    average_steps = total_steps / 10
    return average_reward, average_steps

# Funció per avaluar els tres models
def evaluate_all_models(models, eval_envs):
    for target_desire_factor, (model, eval_env) in zip(target_desire_factors, zip(models, eval_envs)):
        print(f"\nAvaluant el millor model per target_desire_factor = {target_desire_factor}:")
        average_reward, average_steps = evaluate_trained_model(model, eval_env)
        print(f"Recompensa mitjana: {average_reward}, Passos mitjans per episodi: {average_steps}")

# Entrenament dels tres models
models = []
eval_envs = []
for target_desire_factor in target_desire_factors:
    print(f"\n{'-'*50}")
    print(f"Entrenament amb target_desire_factor = {target_desire_factor}")
    model, eval_env = train_agent(target_desire_factor)
    models.append(model)
    eval_envs.append(eval_env)
    print(f"\n{'-'*50}")

# Avaluem els tres models
evaluate_all_models(models, eval_envs)
# Out:
# --------------------------------------------------
# Entrenament amb target_desire_factor = 0
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Evaluació inicial per target_desire_factor = 0:
# Initial evaluation: (25.747312311489708, 28.0)
# Iniciant l'entrenament per target_desire_factor = 0...
# Eval num_timesteps=2000, episode_reward=7.95 +/- 0.77
# Episode length: 8.80 +/- 0.75
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 8.8      |
# |    mean_reward     | 7.95     |
# | time/              |          |
# |    total_timesteps | 2000     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | 19.7     |
# | time/              |          |
# |    fps             | 1602     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Eval num_timesteps=4000, episode_reward=95.56 +/- 80.03
# Episode length: 100.80 +/- 81.14
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 101         |
# |    mean_reward          | 95.6        |
# | time/                   |             |
# |    total_timesteps      | 4000        |
# | train/                  |             |
# |    approx_kl            | 0.008062258 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | 0.00686     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.84        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 44.5        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.2     |
# |    ep_rew_mean     | 24       |
# | time/              |          |
# |    fps             | 1074     |
# |    iterations      | 2        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Eval num_timesteps=6000, episode_reward=194.48 +/- 116.84
# Episode length: 204.40 +/- 118.29
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 204         |
# |    mean_reward          | 194         |
# | time/                   |             |
# |    total_timesteps      | 6000        |
# | train/                  |             |
# |    approx_kl            | 0.008905521 |
# |    clip_fraction        | 0.0529      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.672      |
# |    explained_variance   | 0.0241      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.7        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 37.2        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33.1     |
# |    ep_rew_mean     | 30.3     |
# | time/              |          |
# |    fps             | 935      |
# |    iterations      | 3        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 6144     |
# ---------------------------------
# Eval num_timesteps=8000, episode_reward=435.27 +/- 122.90
# Episode length: 440.20 +/- 119.60
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 440         |
# |    mean_reward          | 435         |
# | time/                   |             |
# |    total_timesteps      | 8000        |
# | train/                  |             |
# |    approx_kl            | 0.008287595 |
# |    clip_fraction        | 0.0834      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.638      |
# |    explained_variance   | 0.166       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.6        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0196     |
# |    value_loss           | 41.4        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.8     |
# |    ep_rew_mean     | 39.3     |
# | time/              |          |
# |    fps             | 831      |
# |    iterations      | 4        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 8192     |
# ---------------------------------
# Eval num_timesteps=10000, episode_reward=338.34 +/- 148.46
# Episode length: 345.80 +/- 145.04
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 346         |
# |    mean_reward          | 338         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.008446557 |
# |    clip_fraction        | 0.0692      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.617      |
# |    explained_variance   | 0.273       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19          |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 50.1        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 58.7     |
# |    ep_rew_mean     | 54       |
# | time/              |          |
# |    fps             | 792      |
# |    iterations      | 5        |
# |    time_elapsed    | 12       |
# |    total_timesteps | 10240    |
# ---------------------------------
# Eval num_timesteps=12000, episode_reward=425.91 +/- 89.32
# Episode length: 431.00 +/- 85.70
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 431         |
# |    mean_reward          | 426         |
# | time/                   |             |
# |    total_timesteps      | 12000       |
# | train/                  |             |
# |    approx_kl            | 0.007974967 |
# |    clip_fraction        | 0.0655      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.59       |
# |    explained_variance   | 0.475       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.1        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 55.9        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74       |
# |    ep_rew_mean     | 68.2     |
# | time/              |          |
# |    fps             | 760      |
# |    iterations      | 6        |
# |    time_elapsed    | 16       |
# |    total_timesteps | 12288    |
# ---------------------------------
# Eval num_timesteps=14000, episode_reward=414.62 +/- 101.63
# Episode length: 420.80 +/- 99.22
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 421        |
# |    mean_reward          | 415        |
# | time/                   |            |
# |    total_timesteps      | 14000      |
# | train/                  |            |
# |    approx_kl            | 0.00995865 |
# |    clip_fraction        | 0.0858     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.586     |
# |    explained_variance   | 0.387      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 24         |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0112    |
# |    value_loss           | 51.1       |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90.2     |
# |    ep_rew_mean     | 83.6     |
# | time/              |          |
# |    fps             | 737      |
# |    iterations      | 7        |
# |    time_elapsed    | 19       |
# |    total_timesteps | 14336    |
# ---------------------------------
# Eval num_timesteps=16000, episode_reward=249.82 +/- 81.92
# Episode length: 258.00 +/- 81.74
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 258         |
# |    mean_reward          | 250         |
# | time/                   |             |
# |    total_timesteps      | 16000       |
# | train/                  |             |
# |    approx_kl            | 0.007066078 |
# |    clip_fraction        | 0.0814      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.57       |
# |    explained_variance   | 0.647       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.5        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 48.2        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    fps             | 733      |
# |    iterations      | 8        |
# |    time_elapsed    | 22       |
# |    total_timesteps | 16384    |
# ---------------------------------
# Eval num_timesteps=18000, episode_reward=240.16 +/- 65.17
# Episode length: 248.60 +/- 64.94
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 249         |
# |    mean_reward          | 240         |
# | time/                   |             |
# |    total_timesteps      | 18000       |
# | train/                  |             |
# |    approx_kl            | 0.010533303 |
# |    clip_fraction        | 0.0973      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.568      |
# |    explained_variance   | 0.773       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.96        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00713    |
# |    value_loss           | 33          |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 125      |
# |    ep_rew_mean     | 116      |
# | time/              |          |
# |    fps             | 727      |
# |    iterations      | 9        |
# |    time_elapsed    | 25       |
# |    total_timesteps | 18432    |
# ---------------------------------
# Eval num_timesteps=20000, episode_reward=389.93 +/- 96.69
# Episode length: 395.80 +/- 93.63
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 396         |
# |    mean_reward          | 390         |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.007111377 |
# |    clip_fraction        | 0.0949      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.543      |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.8        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00847    |
# |    value_loss           | 51.7        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 141      |
# |    ep_rew_mean     | 132      |
# | time/              |          |
# |    fps             | 716      |
# |    iterations      | 10       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 20480    |
# ---------------------------------
#
# --------------------------------------------------
#
# --------------------------------------------------
# Entrenament amb target_desire_factor = 0.5
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Evaluació inicial per target_desire_factor = 0.5:
# Initial evaluation: (17.923035468925217, 19.6)
# Iniciant l'entrenament per target_desire_factor = 0.5...
# Eval num_timesteps=2000, episode_reward=18.26 +/- 6.30
# Episode length: 20.60 +/- 6.25
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 20.6     |
# |    mean_reward     | 18.3     |
# | time/              |          |
# |    total_timesteps | 2000     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.3     |
# |    ep_rew_mean     | 20.6     |
# | time/              |          |
# |    fps             | 1550     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Eval num_timesteps=4000, episode_reward=79.38 +/- 22.59
# Episode length: 86.00 +/- 21.46
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 86           |
# |    mean_reward          | 79.4         |
# | time/                   |              |
# |    total_timesteps      | 4000         |
# | train/                  |              |
# |    approx_kl            | 0.0076442068 |
# |    clip_fraction        | 0.0721       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.687       |
# |    explained_variance   | 0.0081       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.65         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0105      |
# |    value_loss           | 48.3         |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29       |
# |    ep_rew_mean     | 26.8     |
# | time/              |          |
# |    fps             | 1048     |
# |    iterations      | 2        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Eval num_timesteps=6000, episode_reward=109.24 +/- 87.11
# Episode length: 115.40 +/- 89.59
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 115         |
# |    mean_reward          | 109         |
# | time/                   |             |
# |    total_timesteps      | 6000        |
# | train/                  |             |
# |    approx_kl            | 0.009607598 |
# |    clip_fraction        | 0.0729      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.0741      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0175     |
# |    value_loss           | 33.3        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33.8     |
# |    ep_rew_mean     | 31       |
# | time/              |          |
# |    fps             | 947      |
# |    iterations      | 3        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 6144     |
# ---------------------------------
# Eval num_timesteps=8000, episode_reward=220.07 +/- 139.40
# Episode length: 245.40 +/- 136.58
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 245         |
# |    mean_reward          | 220         |
# | time/                   |             |
# |    total_timesteps      | 8000        |
# | train/                  |             |
# |    approx_kl            | 0.007707377 |
# |    clip_fraction        | 0.0762      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.639      |
# |    explained_variance   | 0.219       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 43.6        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.7     |
# |    ep_rew_mean     | 38.8     |
# | time/              |          |
# |    fps             | 877      |
# |    iterations      | 4        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 8192     |
# ---------------------------------
# Eval num_timesteps=10000, episode_reward=144.73 +/- 12.99
# Episode length: 155.20 +/- 9.66
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 155         |
# |    mean_reward          | 145         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.007902047 |
# |    clip_fraction        | 0.0884      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.611      |
# |    explained_variance   | 0.247       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.1        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0168     |
# |    value_loss           | 52.4        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.6     |
# |    ep_rew_mean     | 51.2     |
# | time/              |          |
# |    fps             | 853      |
# |    iterations      | 5        |
# |    time_elapsed    | 12       |
# |    total_timesteps | 10240    |
# ---------------------------------
# Eval num_timesteps=12000, episode_reward=338.26 +/- 132.15
# Episode length: 363.40 +/- 138.03
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 363          |
# |    mean_reward          | 338          |
# | time/                   |              |
# |    total_timesteps      | 12000        |
# | train/                  |              |
# |    approx_kl            | 0.0076489258 |
# |    clip_fraction        | 0.0492       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.602       |
# |    explained_variance   | 0.391        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.3         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0116      |
# |    value_loss           | 49.2         |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 70.8     |
# |    ep_rew_mean     | 64.6     |
# | time/              |          |
# |    fps             | 815      |
# |    iterations      | 6        |
# |    time_elapsed    | 15       |
# |    total_timesteps | 12288    |
# ---------------------------------
# Eval num_timesteps=14000, episode_reward=348.57 +/- 106.52
# Episode length: 377.20 +/- 119.57
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 377        |
# |    mean_reward          | 349        |
# | time/                   |            |
# |    total_timesteps      | 14000      |
# | train/                  |            |
# |    approx_kl            | 0.00529529 |
# |    clip_fraction        | 0.0432     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.572     |
# |    explained_variance   | 0.399      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 18.3       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0104    |
# |    value_loss           | 58.3       |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85.9     |
# |    ep_rew_mean     | 78.4     |
# | time/              |          |
# |    fps             | 787      |
# |    iterations      | 7        |
# |    time_elapsed    | 18       |
# |    total_timesteps | 14336    |
# ---------------------------------
# Eval num_timesteps=16000, episode_reward=443.23 +/- 83.85
# Episode length: 468.60 +/- 62.80
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 469         |
# |    mean_reward          | 443         |
# | time/                   |             |
# |    total_timesteps      | 16000       |
# | train/                  |             |
# |    approx_kl            | 0.009111461 |
# |    clip_fraction        | 0.0826      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.571      |
# |    explained_variance   | 0.693       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.84        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00829    |
# |    value_loss           | 27.1        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | 91.6     |
# | time/              |          |
# |    fps             | 759      |
# |    iterations      | 8        |
# |    time_elapsed    | 21       |
# |    total_timesteps | 16384    |
# ---------------------------------
# Eval num_timesteps=18000, episode_reward=473.90 +/- 29.65
# Episode length: 500.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 500          |
# |    mean_reward          | 474          |
# | time/                   |              |
# |    total_timesteps      | 18000        |
# | train/                  |              |
# |    approx_kl            | 0.0069066305 |
# |    clip_fraction        | 0.0478       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.573       |
# |    explained_variance   | 0.796        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.961        |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00499     |
# |    value_loss           | 21.6         |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    fps             | 738      |
# |    iterations      | 9        |
# |    time_elapsed    | 24       |
# |    total_timesteps | 18432    |
# ---------------------------------
# Eval num_timesteps=20000, episode_reward=354.54 +/- 104.90
# Episode length: 372.40 +/- 105.21
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 372          |
# |    mean_reward          | 355          |
# | time/                   |              |
# |    total_timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0071407943 |
# |    clip_fraction        | 0.0514       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.553       |
# |    explained_variance   | 0.54         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.1          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00568     |
# |    value_loss           | 42.4         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 138      |
# |    ep_rew_mean     | 126      |
# | time/              |          |
# |    fps             | 731      |
# |    iterations      | 10       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 20480    |
# ---------------------------------
#
# --------------------------------------------------
#
# --------------------------------------------------
# Entrenament amb target_desire_factor = 1
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Evaluació inicial per target_desire_factor = 1:
# Initial evaluation: (18.017426723693767, 19.4)
# Iniciant l'entrenament per target_desire_factor = 1...
# Eval num_timesteps=2000, episode_reward=126.65 +/- 188.83
# Episode length: 129.00 +/- 187.84
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 129      |
# |    mean_reward     | 127      |
# | time/              |          |
# |    total_timesteps | 2000     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.4     |
# |    ep_rew_mean     | 21       |
# | time/              |          |
# |    fps             | 1298     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Eval num_timesteps=4000, episode_reward=255.65 +/- 178.75
# Episode length: 279.00 +/- 181.44
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 279         |
# |    mean_reward          | 256         |
# | time/                   |             |
# |    total_timesteps      | 4000        |
# | train/                  |             |
# |    approx_kl            | 0.008163398 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.0129      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.83        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0162     |
# |    value_loss           | 55          |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26       |
# |    ep_rew_mean     | 24.1     |
# | time/              |          |
# |    fps             | 902      |
# |    iterations      | 2        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Eval num_timesteps=6000, episode_reward=98.00 +/- 27.26
# Episode length: 128.20 +/- 33.52
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 128         |
# |    mean_reward          | 98          |
# | time/                   |             |
# |    total_timesteps      | 6000        |
# | train/                  |             |
# |    approx_kl            | 0.010100905 |
# |    clip_fraction        | 0.0729      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.0604      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0174     |
# |    value_loss           | 30.5        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33.5     |
# |    ep_rew_mean     | 31       |
# | time/              |          |
# |    fps             | 864      |
# |    iterations      | 3        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 6144     |
# ---------------------------------
# Eval num_timesteps=8000, episode_reward=351.43 +/- 83.20
# Episode length: 410.20 +/- 110.53
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 410         |
# |    mean_reward          | 351         |
# | time/                   |             |
# |    total_timesteps      | 8000        |
# | train/                  |             |
# |    approx_kl            | 0.010718942 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.638      |
# |    explained_variance   | 0.231       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0212     |
# |    value_loss           | 42.2        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.2     |
# |    ep_rew_mean     | 41.4     |
# | time/              |          |
# |    fps             | 799      |
# |    iterations      | 4        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 8192     |
# ---------------------------------
# Eval num_timesteps=10000, episode_reward=446.90 +/- 50.18
# Episode length: 479.20 +/- 41.60
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 479         |
# |    mean_reward          | 447         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.009465167 |
# |    clip_fraction        | 0.082       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.61       |
# |    explained_variance   | 0.256       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.6        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0162     |
# |    value_loss           | 57.4        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 61       |
# |    ep_rew_mean     | 56.5     |
# | time/              |          |
# |    fps             | 755      |
# |    iterations      | 5        |
# |    time_elapsed    | 13       |
# |    total_timesteps | 10240    |
# ---------------------------------
# Eval num_timesteps=12000, episode_reward=278.17 +/- 109.71
# Episode length: 322.80 +/- 132.54
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 323         |
# |    mean_reward          | 278         |
# | time/                   |             |
# |    total_timesteps      | 12000       |
# | train/                  |             |
# |    approx_kl            | 0.005323173 |
# |    clip_fraction        | 0.0358      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.592      |
# |    explained_variance   | 0.319       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.1        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00946    |
# |    value_loss           | 57.7        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.4     |
# |    ep_rew_mean     | 69.8     |
# | time/              |          |
# |    fps             | 743      |
# |    iterations      | 6        |
# |    time_elapsed    | 16       |
# |    total_timesteps | 12288    |
# ---------------------------------
# Eval num_timesteps=14000, episode_reward=453.97 +/- 48.20
# Episode length: 485.60 +/- 28.80
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 486          |
# |    mean_reward          | 454          |
# | time/                   |              |
# |    total_timesteps      | 14000        |
# | train/                  |              |
# |    approx_kl            | 0.0056445836 |
# |    clip_fraction        | 0.0689       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.581       |
# |    explained_variance   | 0.418        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.4         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0121      |
# |    value_loss           | 51.9         |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93.5     |
# |    ep_rew_mean     | 86       |
# | time/              |          |
# |    fps             | 721      |
# |    iterations      | 7        |
# |    time_elapsed    | 19       |
# |    total_timesteps | 14336    |
# ---------------------------------
# Eval num_timesteps=16000, episode_reward=456.62 +/- 50.01
# Episode length: 479.60 +/- 40.80
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 480         |
# |    mean_reward          | 457         |
# | time/                   |             |
# |    total_timesteps      | 16000       |
# | train/                  |             |
# |    approx_kl            | 0.004121905 |
# |    clip_fraction        | 0.0338      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.551      |
# |    explained_variance   | 0.46        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.2        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00923    |
# |    value_loss           | 54.1        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 110      |
# |    ep_rew_mean     | 101      |
# | time/              |          |
# |    fps             | 707      |
# |    iterations      | 8        |
# |    time_elapsed    | 23       |
# |    total_timesteps | 16384    |
# ---------------------------------
# Eval num_timesteps=18000, episode_reward=391.13 +/- 43.70
# Episode length: 500.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 500          |
# |    mean_reward          | 391          |
# | time/                   |              |
# |    total_timesteps      | 18000        |
# | train/                  |              |
# |    approx_kl            | 0.0064209076 |
# |    clip_fraction        | 0.058        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.55        |
# |    explained_variance   | 0.695        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.2         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00599     |
# |    value_loss           | 33.8         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 129      |
# |    ep_rew_mean     | 117      |
# | time/              |          |
# |    fps             | 695      |
# |    iterations      | 9        |
# |    time_elapsed    | 26       |
# |    total_timesteps | 18432    |
# ---------------------------------
# Eval num_timesteps=20000, episode_reward=359.32 +/- 132.28
# Episode length: 371.00 +/- 124.43
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 371          |
# |    mean_reward          | 359          |
# | time/                   |              |
# |    total_timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0053087245 |
# |    clip_fraction        | 0.039        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.526       |
# |    explained_variance   | 0.838        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.98         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00325     |
# |    value_loss           | 18.2         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 145      |
# |    ep_rew_mean     | 131      |
# | time/              |          |
# |    fps             | 691      |
# |    iterations      | 10       |
# |    time_elapsed    | 29       |
# |    total_timesteps | 20480    |
# ---------------------------------
#
# --------------------------------------------------
#
# Avaluant el millor model per target_desire_factor = 0:
# Recompensa mitjana: 46.76468276557807, Passos mitjans per episodi: 51.0
#
# Avaluant el millor model per target_desire_factor = 0.5:
# Recompensa mitjana: 364.1394687159499, Passos mitjans per episodi: 414.9
#
# Avaluant el millor model per target_desire_factor = 1:
# Recompensa mitjana: 322.15009696133893, Passos mitjans per episodi: 368.1

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>Comentari:</strong>
# <br><br>
#
# Observant els resultats obtinguts veiem que obtenim el millor rendiment amb un 'target_desire_factor' de 0.5, on l'agent aconsegueix la millor recompensa i el nombre de passos mitjans més alt. Amb el valor 'target_desire_factor = 1', tot i tenir una recompensa acceptable, el model no acaba d'explorar tant com amb el 'target_desire_factor = 0.5'. Pel que fa a quan el valor és 'target_desire_factor = 0', veiem que tenim el pitjor rendiment. Això podria indicar que un objectiu massa fort pot perjudicar l'aprenentatge de l'agent on cal equilibrar l'exploració i l'explotació de l'entorn. Així doncs, aquests resultats suggereixen un equilibri moderat ('target_desire_factor = 0.5') sembla ser el més òptim per aquest entorn.
#
# </div>

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong>Exercici 2.2 (1.25 punts):</strong> Fixant ara target_desire_factor = 1, proposa 2 modificacions de la funció de recompensa únicament de la component que té a veure amb el target i comenta els resultats obtinguts. Utilitza la mateixa estructura que fins ara (callback, model, avaluació inicial...).
# </div>

# %%
#env = CartPoleEnvRandomTarget(render_mode=None,reward_function = 'custom_1',target_desire_factor=0)
#eval_env = CartPoleEnvRandomTarget(render_mode=None,reward_function = 'custom_1',target_desire_factor=0,is_eval = True)

#TODO: Repetir el mateix que en els exercicis anteriors. Callback, model, avaluació inicial, càrrega del millor model i entrenament.
#Al final, analitzar els resultats.
#Repetir per a les dues noves funcions d'error.

# %%
"""
Classic cart-pole system implemented by Rich Sutton et al.
Copied from http://incompleteideas.net/sutton/book/code/pole.c
permalink: https://perma.cc/C9ZM-652R
"""

import math
from typing import Optional, Union

import numpy as np

import gymnasium as gym
from gymnasium import spaces
from gymnasium.envs.classic_control import utils
from gymnasium.error import DependencyNotInstalled



class CartPoleEnvRandomTarget(gym.Env[np.ndarray, Union[int, np.ndarray]]):
    """
    ## Description

    This environment corresponds to a modification of the version of the cart-pole problem described by Barto, Sutton, and Anderson in
    ["Neuronlike Adaptive Elements That Can Solve Difficult Learning Control Problem"](https://ieeexplore.ieee.org/document/6313077).
    A pole is attached by an un-actuated joint to a cart, which moves along a frictionless track.
    The pendulum is placed upright on the cart and the goal is to balance the pole by applying forces
     in the left and right direction on the cart.
     The modification consists on a target appearing into scene. The cart must be as close to the target as posible

    For more details about original cartpole look for source code in gymnasium.
    """


    metadata = {
        "render_modes": ["human", "rgb_array"],
        "render_fps": 50,
    }

    def __init__(
        self,
        target_desire_factor: float = 0.5,
        reward_function: str = "default",
        is_eval=False,
        increased_actions=False,
        render_mode: Optional[str] = None,
    ):

        self.gravity = 9.8
        self.masscart = 1.0
        self.masspole = 0.1
        self.total_mass = self.masspole + self.masscart
        self.length = 0.5  # actually half the pole's length
        self.polemass_length = self.masspole * self.length
        self.force_mag = 10.0
        self.tau = 0.02  # seconds between state updates

        self.max_steps = 500
        self.steps = 0

        # Angle at which to fail the episode
        self.theta_threshold_radians = 12 * 2 * math.pi / 360
        self.x_threshold = 2.4
        self.target_threshold = 2

        high = np.array(
            [
                self.x_threshold * 2,
                np.inf,
                self.theta_threshold_radians * 2,
                np.inf,
                self.target_threshold * 2,
            ],
            dtype=np.float32,
        )
        self.increased_actions = increased_actions
        if self.increased_actions:
            #TODO 3.1: Ampliar l'espai d'observacions
            raise NotImplementedError("Increased actions should be implemented")
        else:
            self.action_space = spaces.Discrete(2)
        self.observation_space = spaces.Box(-high, high, dtype=np.float32)

        self.render_mode = render_mode

        self.screen_width = 600
        self.screen_height = 400
        self.screen = None
        self.clock = None
        self.isopen = True
        self.state: np.ndarray | None = None

        self.steps_beyond_terminated = None

        #TODO 1.3: Tenir en compte si l'entorn és d'avaluació
        self.is_eval = is_eval
        self.target_position_index = None #index to control target position
        self.target_position = self.generate_random_target_position()

        self.target_desire_factor = min(
            max(target_desire_factor, 0), 1
        )  # between 0 and 1
        if reward_function in ["default", "custom", "custom1", "custom2"]:
            self.reward_function = reward_function
        else:
            raise AttributeError("reward function must be either default or custom")

    def generate_random_target_position(
        self,
    ):
        if self.is_eval:
            #TODO 1.3:Tingueu en compte si l'entorn és d'avaluació per situar el target en unes posicions concretes.
            #preset target positions for evaluation mode
            eval_positions = [
                -self.x_threshold,                      # Extrem esquerre
                -self.x_threshold * 0.75,               # 3/4 esquerre
                -self.x_threshold * 0.5,                # 1/2 esquerre
                -self.x_threshold * 0.25,               # 1/4 esquerre
                0.0,                                    # Centre
                self.x_threshold * 0.25,                # 1/4 dret
                self.x_threshold * 0.5,                 # 1/2 dret
                self.x_threshold * 0.75,                # 3/4 dret
                self.x_threshold                        # Extrem dret
            ]
            #select a random position (first execution)
            if self.target_position_index is None:
                self.target_position_index = np.random.randint(0,9)

            #select the target position based on the index
            target_position = eval_positions[self.target_position_index]

            #update the index
            self.target_position_index = (self.target_position_index + 1) % 9
            
            return target_position
        else:
            return np.random.uniform(-self.x_threshold, self.x_threshold)

    def custom_reward(self, target_position, current_position, angle, terminated):
        if self.reward_function == "default":
            #Reward default del cartpole
            return 1 if not terminated else 0
        elif self.reward_function == "custom":
            angle_reward = ( -abs(angle) / (2.0 * self.x_threshold) / self.theta_threshold_radians )
            target_reward = -(abs(target_position - current_position) ** 2) / ((2 * self.x_threshold) ** 2)
            return ( 1 + self.target_desire_factor * target_reward + (1 - self.target_desire_factor) * angle_reward )
        #TODO 2.2: Implementar 2 funcions de reward extra

        elif self.reward_function == "custom1":
            #Custom Reward 1: Recompensa basada en la distància entre la posició del carret i el target
            #Penalitza més l'angle i premia si la posició del carret és a prop del target
            angle_penalty = abs(angle) / self.theta_threshold_radians
            distance_to_target = abs(target_position - current_position)
            target_reward = 1 - (distance_to_target / self.x_threshold) ** 2
            return max(0, target_reward - angle_penalty)
        elif self.reward_function == "custom2":
            #Custom Reward 2: Recompensa per llindar
            #Penalització de l'angle
            angle_penalty = abs(angle) / self.theta_threshold_radians
            #Distància al target
            distance_to_target = abs(target_position - current_position)
            #Penalització contínua de la distància (inspirada en custom1)
            target_reward = 1 - (distance_to_target / self.x_threshold) ** 2
            #Llindar per recompensa extra
            distance_threshold = 0.2  # Llindar de 0.2 unitats al voltant del target
            if distance_to_target <= distance_threshold:
                target_reward += 0.5  # Bonificació si és prou a prop del target
            # Combinació de les components
            return max(0, target_reward - angle_penalty)

        else:
            raise AttributeError("Invalid reward function specified")

    def step(self, action):
        assert self.action_space.contains(
            action
        ), f"{action!r} ({type(action)}) invalid"
        assert self.state is not None, "Call reset before using step method."
        x, x_dot, theta, theta_dot, _ = self.state
        if self.increased_actions:
            force_factor = action - 3
            force = (
                force_factor / 3 * self.force_mag
                if force_factor > 0
                else (force_factor - 1) / 3 * self.force_mag
            )
        else:
            force = self.force_mag if action == 1 else -self.force_mag
        costheta = np.cos(theta)
        sintheta = np.sin(theta)

        # For the interested reader:
        # https://coneural.org/florian/papers/05_cart_pole.pdf
        temp = (
            force + self.polemass_length * np.square(theta_dot) * sintheta
        ) / self.total_mass
        thetaacc = (self.gravity * sintheta - costheta * temp) / (
            self.length
            * (4.0 / 3.0 - self.masspole * np.square(costheta) / self.total_mass)
        )
        xacc = temp - self.polemass_length * thetaacc * costheta / self.total_mass

        x = x + self.tau * x_dot
        x_dot = x_dot + self.tau * xacc
        theta = theta + self.tau * theta_dot
        theta_dot = theta_dot + self.tau * thetaacc

        self.state = np.array(
            (x, x_dot, theta, theta_dot, self.target_position), dtype=np.float64
        ) #Aquest estat es diferent respecte al del cartpole original

        terminated = bool(
            x < -self.x_threshold
            or x > self.x_threshold
            or theta < -self.theta_threshold_radians
            or theta > self.theta_threshold_radians
        )

        reward = self.custom_reward(self.target_position, x, theta, terminated)

        if self.render_mode == "human":
            self.render()

        # truncation=False as the time limit is handled by the `TimeLimit` wrapper added during `make`
        self.steps += 1
        if self.steps >= self.max_steps:
            truncated = True
        else:
            truncated = False
        return np.array(self.state, dtype=np.float32), reward, terminated, truncated, {}

    def reset(
        self,
        *,
        seed: Optional[int] = None,
        options: Optional[dict] = None,
    ):

        super().reset(seed=seed)
        self.steps = 0
        # Note that if you use custom reset bounds, it may lead to out-of-bound
        # state/observations.
        low, high = utils.maybe_parse_reset_bounds(
            options, -0.05, 0.05  # default low
        )  # default high

        self.state = self.np_random.uniform(low=low, high=high, size=(4,)).tolist()
        self.steps_beyond_terminated = None

        #Generar posició aleatòria del target i guardar en l'estat
        self.target_position = self.generate_random_target_position()
        self.state.append(self.target_position)

        self.state = np.array(self.state)
        if self.render_mode == "human":
            self.render()
        return np.array(self.state, dtype=np.float32), {}

    def render(self):
        if self.render_mode is None:
            assert self.spec is not None
            gym.logger.warn(
                "You are calling render method without specifying any render mode. "
                "You can specify the render_mode at initialization, "
                f'e.g. gym.make("{self.spec.id}", render_mode="rgb_array")'
            )
            return

        try:
            import pygame
            from pygame import gfxdraw
        except ImportError as e:
            raise DependencyNotInstalled(
                'pygame is not installed, run `pip install "gymnasium[classic-control]"`'
            ) from e

        if self.screen is None:
            pygame.init()
            if self.render_mode == "human":
                pygame.display.init()
                self.screen = pygame.display.set_mode(
                    (self.screen_width, self.screen_height)
                )
            else:  # mode == "rgb_array"
                self.screen = pygame.Surface((self.screen_width, self.screen_height))
        if self.clock is None:
            self.clock = pygame.time.Clock()

        world_width = self.x_threshold * 2
        scale = self.screen_width / world_width
        polewidth = 10.0
        polelen = scale * (2 * self.length)
        cartwidth = 50.0
        cartheight = 30.0
        targetwidth = 10
        targetheight = 10

        if self.state is None:
            return None

        x = self.state

        self.surf = pygame.Surface((self.screen_width, self.screen_height))
        self.surf.fill((255, 255, 255))

        l, r, t, b = -cartwidth / 2, cartwidth / 2, cartheight / 2, -cartheight / 2
        axleoffset = cartheight / 4.0
        cartx = x[0] * scale + self.screen_width / 2.0  # MIDDLE OF CART
        carty = 100  # TOP OF CART
        cart_coords = [(l, b), (l, t), (r, t), (r, b)]
        cart_coords = [(c[0] + cartx, c[1] + carty) for c in cart_coords]
        gfxdraw.aapolygon(self.surf, cart_coords, (0, 0, 0))
        gfxdraw.filled_polygon(self.surf, cart_coords, (0, 0, 0))

        l, r, t, b = (
            -polewidth / 2,
            polewidth / 2,
            polelen - polewidth / 2,
            -polewidth / 2,
        )

        pole_coords = []
        for coord in [(l, b), (l, t), (r, t), (r, b)]:
            coord = pygame.math.Vector2(coord).rotate_rad(-x[2])
            coord = (coord[0] + cartx, coord[1] + carty + axleoffset)
            pole_coords.append(coord)
        gfxdraw.aapolygon(self.surf, pole_coords, (202, 152, 101))
        gfxdraw.filled_polygon(self.surf, pole_coords, (202, 152, 101))

        gfxdraw.aacircle(
            self.surf,
            int(cartx),
            int(carty + axleoffset),
            int(polewidth / 2),
            (129, 132, 203),
        )
        gfxdraw.filled_circle(
            self.surf,
            int(cartx),
            int(carty + axleoffset),
            int(polewidth / 2),
            (129, 132, 203),
        )

        l, r, t, b = (
            -targetwidth / 2,
            targetwidth / 2,
            targetheight / 2,
            -targetheight / 2,
        )
        axleoffset = targetheight / 4.0
        targetx = x[-1] * scale + self.screen_width / 2.0  # MIDDLE OF target
        targety = 90  # TOP OF target
        target_coords = [(l, b), (l, t), (r, t), (r, b)]
        target_coords = [(c[0] + targetx, c[1] + targety) for c in target_coords]
        gfxdraw.aapolygon(self.surf, target_coords, (10, 255, 10))
        gfxdraw.filled_polygon(self.surf, target_coords, (10, 255, 10))

        gfxdraw.hline(self.surf, 0, self.screen_width, carty, (0, 0, 0))

        self.surf = pygame.transform.flip(self.surf, False, True)
        self.screen.blit(self.surf, (0, 0))
        if self.render_mode == "human":
            pygame.event.pump()
            self.clock.tick(self.metadata["render_fps"])
            pygame.display.flip()

        elif self.render_mode == "rgb_array":
            return np.transpose(
                np.array(pygame.surfarray.pixels3d(self.screen)), axes=(1, 0, 2)
            )

    def close(self):
        if self.screen is not None:
            import pygame

            pygame.display.quit()
            pygame.quit()
            self.isopen = False

# %%
target_desire_factor = 1
reward_functions = ['custom1', 'custom2']  # Funcions de recompensa a comparar
STEPS = 20000
EVAL_FREQ = 2000

# Funció per entrenar l'agent per una reward_function
def train_agent(reward_function):
    # Creem l'entorn d'entrenament i d'avaluació amb el valor fix de target_desire_factor
    env = CartPoleEnvRandomTarget(render_mode=None, reward_function=reward_function, target_desire_factor=target_desire_factor)
    eval_env = CartPoleEnvRandomTarget(render_mode=None, reward_function=reward_function, target_desire_factor=target_desire_factor, is_eval=True)

    # Creem l'agent (PPO en aquest cas)
    model = PPO("MlpPolicy", env, verbose=1)
    
    # Avaluació inicial abans de l'entrenament
    print(f"Evaluació inicial per reward_function = {reward_function}:")
    initial_eval = evaluate_trained_model(model, eval_env)  # Avaluem el model sense entrenar
    print(f"Initial evaluation: {initial_eval}")

    # Callback per a l'avaluació durant l'entrenament
    eval_callback = EvalCallback(
        DummyVecEnv([lambda: eval_env]),  # Creem l'entorn vectoritzat dins del callback
        best_model_save_path=f"./best_model_{reward_function}", 
        log_path=f"./logs_{reward_function}", 
        eval_freq=EVAL_FREQ,  # Establert a EVAL_FREQ
        verbose=1
    )

    # Entrenem el model
    print(f"Iniciant l'entrenament per reward_function = {reward_function}...")
    model.learn(total_timesteps=STEPS, callback=eval_callback)  # Establert a STEPS

    # Carreguem el millor model
    model = PPO.load(f"./best_model_{reward_function}/best_model.zip")
    
    return model, eval_env

# Funció per avaluar el model entrenat
def evaluate_trained_model(model, eval_env):
    total_reward = 0
    total_steps = 0
    for _ in range(10):  # Evaluem durant 10 episodis
        obs, _ = eval_env.reset()  # Ens assegurem d'obeir només l'observació
        done = False
        episode_reward = 0
        steps = 0
        while not done:
            action, _ = model.predict(obs)
            result = eval_env.step(action)
            # Desempaquetem els primers 4 elements
            obs, reward, done, _ = result[:4]
            episode_reward += reward
            steps += 1
        total_reward += episode_reward
        total_steps += steps
    
    average_reward = total_reward / 10
    average_steps = total_steps / 10
    return average_reward, average_steps

# Entrenament dels dos models amb funcions de recompensa diferents
models = []
eval_envs = []

for reward_function in reward_functions:
    print(f"\n{'-'*50}")
    print(f"Entrenament amb reward_function = {reward_function}")
    model, eval_env = train_agent(reward_function)
    models.append(model)
    eval_envs.append(eval_env)
    print(f"\n{'-'*50}")

# Avaluació comparativa dels dos models
for reward_function, (model, eval_env) in zip(reward_functions, zip(models, eval_envs)):
    print(f"\nEvaluant el millor model amb reward_function = {reward_function}:")
    average_reward, average_steps = evaluate_trained_model(model, eval_env)
    print(f"Recompensa mitjana: {average_reward}, Passos mitjans per episodi: {average_steps}")
# Out:
# --------------------------------------------------
# Entrenament amb reward_function = custom1
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Evaluació inicial per reward_function = custom1:
# Initial evaluation: (5.431754500622983, 22.9)
# Iniciant l'entrenament per reward_function = custom1...
# Eval num_timesteps=2000, episode_reward=4.22 +/- 1.34
# Episode length: 9.60 +/- 0.80
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 9.6      |
# |    mean_reward     | 4.22     |
# | time/              |          |
# |    total_timesteps | 2000     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | 8.03     |
# | time/              |          |
# |    fps             | 1569     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Eval num_timesteps=4000, episode_reward=53.74 +/- 75.14
# Episode length: 172.40 +/- 168.40
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 172         |
# |    mean_reward          | 53.7        |
# | time/                   |             |
# |    total_timesteps      | 4000        |
# | train/                  |             |
# |    approx_kl            | 0.010093223 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | -0.00554    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.19        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 11          |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27       |
# |    ep_rew_mean     | 10.4     |
# | time/              |          |
# |    fps             | 1008     |
# |    iterations      | 2        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Eval num_timesteps=6000, episode_reward=139.92 +/- 163.03
# Episode length: 247.60 +/- 206.43
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 248         |
# |    mean_reward          | 140         |
# | time/                   |             |
# |    total_timesteps      | 6000        |
# | train/                  |             |
# |    approx_kl            | 0.009673661 |
# |    clip_fraction        | 0.0697      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.662      |
# |    explained_variance   | 0.17        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.1         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 14.3        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.9     |
# |    ep_rew_mean     | 14.2     |
# | time/              |          |
# |    fps             | 889      |
# |    iterations      | 3        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 6144     |
# ---------------------------------
# Eval num_timesteps=8000, episode_reward=52.81 +/- 31.59
# Episode length: 108.00 +/- 29.33
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 108          |
# |    mean_reward          | 52.8         |
# | time/                   |              |
# |    total_timesteps      | 8000         |
# | train/                  |              |
# |    approx_kl            | 0.0060983393 |
# |    clip_fraction        | 0.0576       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.634       |
# |    explained_variance   | 0.454        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.4         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.013       |
# |    value_loss           | 17.7         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.4     |
# |    ep_rew_mean     | 17.1     |
# | time/              |          |
# |    fps             | 863      |
# |    iterations      | 4        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 8192     |
# ---------------------------------
# Eval num_timesteps=10000, episode_reward=118.29 +/- 140.45
# Episode length: 247.00 +/- 129.07
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 247          |
# |    mean_reward          | 118          |
# | time/                   |              |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0072637796 |
# |    clip_fraction        | 0.0802       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.61        |
# |    explained_variance   | 0.56         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.61         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0143      |
# |    value_loss           | 23.5         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 57.8     |
# |    ep_rew_mean     | 20.6     |
# | time/              |          |
# |    fps             | 827      |
# |    iterations      | 5        |
# |    time_elapsed    | 12       |
# |    total_timesteps | 10240    |
# ---------------------------------
# Eval num_timesteps=12000, episode_reward=302.78 +/- 135.78
# Episode length: 463.40 +/- 73.20
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 463          |
# |    mean_reward          | 303          |
# | time/                   |              |
# |    total_timesteps      | 12000        |
# | train/                  |              |
# |    approx_kl            | 0.0055997353 |
# |    clip_fraction        | 0.0575       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.598       |
# |    explained_variance   | 0.616        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.38         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0104      |
# |    value_loss           | 18.6         |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73       |
# |    ep_rew_mean     | 25.7     |
# | time/              |          |
# |    fps             | 785      |
# |    iterations      | 6        |
# |    time_elapsed    | 15       |
# |    total_timesteps | 12288    |
# ---------------------------------
# Eval num_timesteps=14000, episode_reward=314.18 +/- 198.25
# Episode length: 494.40 +/- 11.20
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 494         |
# |    mean_reward          | 314         |
# | time/                   |             |
# |    total_timesteps      | 14000       |
# | train/                  |             |
# |    approx_kl            | 0.003977231 |
# |    clip_fraction        | 0.0155      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.603      |
# |    explained_variance   | 0.667       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.05        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00257    |
# |    value_loss           | 13.4        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 87.1     |
# |    ep_rew_mean     | 30.4     |
# | time/              |          |
# |    fps             | 754      |
# |    iterations      | 7        |
# |    time_elapsed    | 19       |
# |    total_timesteps | 14336    |
# ---------------------------------
# Eval num_timesteps=16000, episode_reward=208.48 +/- 42.39
# Episode length: 430.20 +/- 86.05
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 430          |
# |    mean_reward          | 208          |
# | time/                   |              |
# |    total_timesteps      | 16000        |
# | train/                  |              |
# |    approx_kl            | 0.0065383567 |
# |    clip_fraction        | 0.0627       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.574       |
# |    explained_variance   | 0.801        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.21         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00911     |
# |    value_loss           | 18.5         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 105      |
# |    ep_rew_mean     | 38.8     |
# | time/              |          |
# |    fps             | 735      |
# |    iterations      | 8        |
# |    time_elapsed    | 22       |
# |    total_timesteps | 16384    |
# ---------------------------------
# Eval num_timesteps=18000, episode_reward=342.96 +/- 127.89
# Episode length: 409.60 +/- 84.59
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 410         |
# |    mean_reward          | 343         |
# | time/                   |             |
# |    total_timesteps      | 18000       |
# | train/                  |             |
# |    approx_kl            | 0.006058406 |
# |    clip_fraction        | 0.051       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.563      |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.23        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0068     |
# |    value_loss           | 17.4        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 124      |
# |    ep_rew_mean     | 49.2     |
# | time/              |          |
# |    fps             | 723      |
# |    iterations      | 9        |
# |    time_elapsed    | 25       |
# |    total_timesteps | 18432    |
# ---------------------------------
# Eval num_timesteps=20000, episode_reward=311.14 +/- 127.39
# Episode length: 451.20 +/- 97.60
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 451         |
# |    mean_reward          | 311         |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.006623484 |
# |    clip_fraction        | 0.038       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.549      |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.37        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00568    |
# |    value_loss           | 8.61        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 141      |
# |    ep_rew_mean     | 61.2     |
# | time/              |          |
# |    fps             | 711      |
# |    iterations      | 10       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 20480    |
# ---------------------------------
#
# --------------------------------------------------
#
# --------------------------------------------------
# Entrenament amb reward_function = custom2
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Evaluació inicial per reward_function = custom2:
# Initial evaluation: (9.479714684864915, 20.9)
# Iniciant l'entrenament per reward_function = custom2...
# Eval num_timesteps=2000, episode_reward=1.30 +/- 1.21
# Episode length: 9.00 +/- 0.63
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 9        |
# |    mean_reward     | 1.3      |
# | time/              |          |
# |    total_timesteps | 2000     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.8     |
# |    ep_rew_mean     | 10.3     |
# | time/              |          |
# |    fps             | 1616     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Eval num_timesteps=4000, episode_reward=93.25 +/- 137.60
# Episode length: 152.20 +/- 138.31
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 152         |
# |    mean_reward          | 93.3        |
# | time/                   |             |
# |    total_timesteps      | 4000        |
# | train/                  |             |
# |    approx_kl            | 0.008398124 |
# |    clip_fraction        | 0.0952      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00169     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.18        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00953    |
# |    value_loss           | 16.6        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.4     |
# |    ep_rew_mean     | 11.4     |
# | time/              |          |
# |    fps             | 1046     |
# |    iterations      | 2        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Eval num_timesteps=6000, episode_reward=163.33 +/- 288.35
# Episode length: 181.80 +/- 163.42
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 182        |
# |    mean_reward          | 163        |
# | time/                   |            |
# |    total_timesteps      | 6000       |
# | train/                  |            |
# |    approx_kl            | 0.00732284 |
# |    clip_fraction        | 0.0491     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.669     |
# |    explained_variance   | 0.159      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.43       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0111    |
# |    value_loss           | 15.7       |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.3     |
# |    ep_rew_mean     | 11.6     |
# | time/              |          |
# |    fps             | 930      |
# |    iterations      | 3        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 6144     |
# ---------------------------------
# Eval num_timesteps=8000, episode_reward=67.12 +/- 88.14
# Episode length: 265.20 +/- 127.53
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 265          |
# |    mean_reward          | 67.1         |
# | time/                   |              |
# |    total_timesteps      | 8000         |
# | train/                  |              |
# |    approx_kl            | 0.0068076113 |
# |    clip_fraction        | 0.0553       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.649       |
# |    explained_variance   | 0.383        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.19         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0113      |
# |    value_loss           | 12.5         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.2     |
# |    ep_rew_mean     | 13.9     |
# | time/              |          |
# |    fps             | 867      |
# |    iterations      | 4        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 8192     |
# ---------------------------------
# Eval num_timesteps=10000, episode_reward=398.67 +/- 170.29
# Episode length: 480.40 +/- 39.20
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 480          |
# |    mean_reward          | 399          |
# | time/                   |              |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0074765086 |
# |    clip_fraction        | 0.0795       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.622       |
# |    explained_variance   | 0.398        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.36         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0151      |
# |    value_loss           | 13.5         |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 58.1     |
# |    ep_rew_mean     | 21.2     |
# | time/              |          |
# |    fps             | 803      |
# |    iterations      | 5        |
# |    time_elapsed    | 12       |
# |    total_timesteps | 10240    |
# ---------------------------------
# Eval num_timesteps=12000, episode_reward=184.32 +/- 191.62
# Episode length: 256.20 +/- 142.49
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 256          |
# |    mean_reward          | 184          |
# | time/                   |              |
# |    total_timesteps      | 12000        |
# | train/                  |              |
# |    approx_kl            | 0.0062045213 |
# |    clip_fraction        | 0.0498       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.604       |
# |    explained_variance   | 0.526        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.01         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0112      |
# |    value_loss           | 26.9         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74       |
# |    ep_rew_mean     | 31.2     |
# | time/              |          |
# |    fps             | 787      |
# |    iterations      | 6        |
# |    time_elapsed    | 15       |
# |    total_timesteps | 12288    |
# ---------------------------------
# Eval num_timesteps=14000, episode_reward=80.72 +/- 30.98
# Episode length: 173.00 +/- 18.99
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 173        |
# |    mean_reward          | 80.7       |
# | time/                   |            |
# |    total_timesteps      | 14000      |
# | train/                  |            |
# |    approx_kl            | 0.00471461 |
# |    clip_fraction        | 0.0448     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.604     |
# |    explained_variance   | 0.596      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.33       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00929   |
# |    value_loss           | 25.8       |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 89       |
# |    ep_rew_mean     | 37.7     |
# | time/              |          |
# |    fps             | 784      |
# |    iterations      | 7        |
# |    time_elapsed    | 18       |
# |    total_timesteps | 14336    |
# ---------------------------------
# Eval num_timesteps=16000, episode_reward=468.47 +/- 128.55
# Episode length: 481.00 +/- 38.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 481          |
# |    mean_reward          | 468          |
# | time/                   |              |
# |    total_timesteps      | 16000        |
# | train/                  |              |
# |    approx_kl            | 0.0053849504 |
# |    clip_fraction        | 0.0493       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.596       |
# |    explained_variance   | 0.783        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.81         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00742     |
# |    value_loss           | 20.8         |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 107      |
# |    ep_rew_mean     | 48.2     |
# | time/              |          |
# |    fps             | 758      |
# |    iterations      | 8        |
# |    time_elapsed    | 21       |
# |    total_timesteps | 16384    |
# ---------------------------------
# Eval num_timesteps=18000, episode_reward=268.38 +/- 171.33
# Episode length: 395.40 +/- 106.77
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 395          |
# |    mean_reward          | 268          |
# | time/                   |              |
# |    total_timesteps      | 18000        |
# | train/                  |              |
# |    approx_kl            | 0.0039640004 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.567       |
# |    explained_variance   | 0.839        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.69         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00682     |
# |    value_loss           | 30.5         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 123      |
# |    ep_rew_mean     | 58.7     |
# | time/              |          |
# |    fps             | 745      |
# |    iterations      | 9        |
# |    time_elapsed    | 24       |
# |    total_timesteps | 18432    |
# ---------------------------------
# Eval num_timesteps=20000, episode_reward=197.02 +/- 125.57
# Episode length: 417.60 +/- 103.60
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 418          |
# |    mean_reward          | 197          |
# | time/                   |              |
# |    total_timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0038861553 |
# |    clip_fraction        | 0.0259       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.556       |
# |    explained_variance   | 0.834        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.72         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00593     |
# |    value_loss           | 34.7         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 138      |
# |    ep_rew_mean     | 68.8     |
# | time/              |          |
# |    fps             | 731      |
# |    iterations      | 10       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 20480    |
# ---------------------------------
#
# --------------------------------------------------
#
# Evaluant el millor model amb reward_function = custom1:
# Recompensa mitjana: 182.85731443744254, Passos mitjans per episodi: 397.3
#
# Evaluant el millor model amb reward_function = custom2:
# Recompensa mitjana: 116.16873883312356, Passos mitjans per episodi: 249.5

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>Comentari:</strong>
# <br><br>
#
# #### Recompensa custom 1 : Recompensa de l'angle i distància
#
#
# Aquesta comput de recompensa penalitza l'angle i recompensa en funció de la distància entre el carro i el target. L'objectiu és guiar el carro cap al target, tot mantenint el pal en una posició estable (angle petit).
#
# #### Recompensa custom 2 : Recompensa de llindar
#
# Incentiva que el carro s'acosti al target i dona una bonificació addicional quan la distància entre el carri i el target estigui dins d'un llindar petit, penalitzant angles grans.
#
#
# Després d'analitzar els resultats, podem veure que la recompensa mitjana és molt més gran en la primera funció de recompensa que en la segona. A la vegada, obtenim una mitjana de passos per episodi també molt més gran.
#
# </div>

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong>Exercici 2.3 (0.5 punts):</strong> A nivell teòric i suposant un temps d'entrenament més llarg amb uns hiperparàmetres més òptims, podríem arribar a esperar mai d'un agent amb una alpha = 1 (només es fixa en estar a prop del target) que aprengui a mantenir el pal en equilibri?
#     Sabries trobar una equivalència amb el cas sense el target?
# </div>

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>Comentari:</strong>
# <br><br>
#
# No, no podríem esperar que un agent amb un alpha = 1 (que només es fixa en estar a prop del target) aprengui mai a mantenir el pal en equilibri. Aquesta configuració portaria a una desconnexió entre l'objectiu d'equilibrar el pal i l'objectiu de seguir el target.
#
# En cas de no tenir target, l'única preocupació de l'agent és la de mantenir el pal en equilibri, fent que es minimitzi l'angle del pal respecte a la vertical i minimitzant els desplaçaments del carro. Donat que en context del CartPole tenim dos objectius (està a prop del target i mantenir el pal el més vertical possible), el més equilibrat seria en un punt intermedi (voltants alpha = 0.5) per tenir un compromís entre els dos objectius.
# </div>

# %% [markdown]
# # 3. Increment de l'espai d'accions (1.5 pts)

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong>Exercici 3.1 (0.5 punts):</strong> Modifica el codi de tal manera que ara existeixin 6 accions en comptes de 2:
#     <ul>
#     <li>Accions 6,5,4, fer un 100%, 66% i 33% de força positiva respectivament</li>
#     <li>Accions 1,2,3, fer un 100%, 66% i 33% de força negativa respectivament</li>
#     </ul>
#
# <strong>NOTA: A partir d'ara i fins al final de la pràctica es farà servir la recompensa custom que ja venia implementada amb target_desire_factor = 1</strong>
# </div>

# %%
"""
Classic cart-pole system implemented by Rich Sutton et al.
Copied from http://incompleteideas.net/sutton/book/code/pole.c
permalink: https://perma.cc/C9ZM-652R
"""

import math
from typing import Optional, Union

import numpy as np

import gymnasium as gym
from gymnasium import spaces
from gymnasium.envs.classic_control import utils
from gymnasium.error import DependencyNotInstalled



class CartPoleEnvRandomTarget(gym.Env[np.ndarray, Union[int, np.ndarray]]):
    """
    ## Description

    This environment corresponds to a modification of the version of the cart-pole problem described by Barto, Sutton, and Anderson in
    ["Neuronlike Adaptive Elements That Can Solve Difficult Learning Control Problem"](https://ieeexplore.ieee.org/document/6313077).
    A pole is attached by an un-actuated joint to a cart, which moves along a frictionless track.
    The pendulum is placed upright on the cart and the goal is to balance the pole by applying forces
     in the left and right direction on the cart.
     The modification consists on a target appearing into scene. The cart must be as close to the target as posible

    For more details about original cartpole look for source code in gymnasium.
    """


    metadata = {
        "render_modes": ["human", "rgb_array"],
        "render_fps": 50,
    }

    def __init__(
        self,
        target_desire_factor: float = 0.5,
        reward_function: str = "default",
        is_eval=False,
        increased_actions=False,
        render_mode: Optional[str] = None,
    ):

        self.gravity = 9.8
        self.masscart = 1.0
        self.masspole = 0.1
        self.total_mass = self.masspole + self.masscart
        self.length = 0.5  # actually half the pole's length
        self.polemass_length = self.masspole * self.length
        self.force_mag = 10.0
        self.tau = 0.02  # seconds between state updates

        self.max_steps = 500
        self.steps = 0

        # Angle at which to fail the episode
        self.theta_threshold_radians = 12 * 2 * math.pi / 360
        self.x_threshold = 2.4
        self.target_threshold = 2

        high = np.array(
            [
                self.x_threshold * 2,
                np.inf,
                self.theta_threshold_radians * 2,
                np.inf,
                self.target_threshold * 2,
            ],
            dtype=np.float32,
        )
        self.increased_actions = increased_actions
        if self.increased_actions:
            #TODO 3.1: Ampliar l'espai d'observacions
            self.action_space = spaces.Discrete(6)
        else:
            self.action_space = spaces.Discrete(2)
        self.observation_space = spaces.Box(-high, high, dtype=np.float32)

        self.render_mode = render_mode

        self.screen_width = 600
        self.screen_height = 400
        self.screen = None
        self.clock = None
        self.isopen = True
        self.state: np.ndarray | None = None

        self.steps_beyond_terminated = None

        #TODO 1.3: Tenir en compte si l'entorn és d'avaluació
        self.is_eval = is_eval
        self.target_position_index = None #index to control target position
        self.target_position = self.generate_random_target_position()

        self.target_desire_factor = min(
            max(target_desire_factor, 0), 1
        )  # between 0 and 1
        if reward_function in ["default", "custom", "custom1", "custom2"]:
            self.reward_function = reward_function
        else:
            raise AttributeError("reward function must be either default or custom")

    def generate_random_target_position(
        self,
    ):
        if self.is_eval:
            #TODO 1.3:Tingueu en compte si l'entorn és d'avaluació per situar el target en unes posicions concretes.
            #preset target positions for evaluation mode
            eval_positions = [
                -self.x_threshold,                      # Extrem esquerre
                -self.x_threshold * 0.75,               # 3/4 esquerre
                -self.x_threshold * 0.5,                # 1/2 esquerre
                -self.x_threshold * 0.25,               # 1/4 esquerre
                0.0,                                    # Centre
                self.x_threshold * 0.25,                # 1/4 dret
                self.x_threshold * 0.5,                 # 1/2 dret
                self.x_threshold * 0.75,                # 3/4 dret
                self.x_threshold                        # Extrem dret
            ]
            #select a random position (first execution)
            if self.target_position_index is None:
                self.target_position_index = np.random.randint(0,9)

            #select the target position based on the index
            target_position = eval_positions[self.target_position_index]

            #update the index
            self.target_position_index = (self.target_position_index + 1) % 9
            
            return target_position
        else:
            return np.random.uniform(-self.x_threshold, self.x_threshold)

    def custom_reward(self, target_position, current_position, angle, terminated):
        if self.reward_function == "default":
            #Reward default del cartpole
            return 1 if not terminated else 0
        elif self.reward_function == "custom":
            angle_reward = ( -abs(angle) / (2.0 * self.x_threshold) / self.theta_threshold_radians )
            target_reward = -(abs(target_position - current_position) ** 2) / ((2 * self.x_threshold) ** 2)
            return ( 1 + self.target_desire_factor * target_reward + (1 - self.target_desire_factor) * angle_reward )
        #TODO 2.2: Implementar 2 funcions de reward extra

        elif self.reward_function == "custom1":
            #Custom Reward 1: Recompensa basada en la distància entre la posició del carret i el target
            #Penalitza més l'angle i premia si la posició del carret és a prop del target
            angle_penalty = abs(angle) / self.theta_threshold_radians
            distance_to_target = abs(target_position - current_position)
            target_reward = 1 - (distance_to_target / self.x_threshold) ** 2
            return max(0, target_reward - angle_penalty)
        elif self.reward_function == "custom2":
            #Custom Reward 2: Recompensa per llindar
            #Penalització de l'angle
            angle_penalty = abs(angle) / self.theta_threshold_radians
            #Distància al target
            distance_to_target = abs(target_position - current_position)
            #Penalització contínua de la distància (inspirada en custom1)
            target_reward = 1 - (distance_to_target / self.x_threshold) ** 2
            #Llindar per recompensa extra
            distance_threshold = 0.2  # Llindar de 0.2 unitats al voltant del target
            if distance_to_target <= distance_threshold:
                target_reward += 0.5  # Bonificació si és prou a prop del target
            # Combinació de les components
            return max(0, target_reward - angle_penalty)

        else:
            raise AttributeError("Invalid reward function specified")

    def step(self, action):
        assert self.action_space.contains(
            action
        ), f"{action!r} ({type(action)}) invalid"
        assert self.state is not None, "Call reset before using step method."
        x, x_dot, theta, theta_dot, _ = self.state
        if self.increased_actions:
            # Accions negatives (0, 1, 2)
            if action in [0, 1, 2]:  
                force_multipliers = [1.0, 0.66, 0.33]
                force = -force_multipliers[action] * self.force_mag
            # Accions positives (3, 4, 5)
            elif action in [3, 4, 5]:  
                force_multipliers = [1.0, 0.66, 0.33]
                force = force_multipliers[action - 3] * self.force_mag
        else:
            force = self.force_mag if action == 1 else -self.force_mag
        costheta = np.cos(theta)
        sintheta = np.sin(theta)

        # For the interested reader:
        # https://coneural.org/florian/papers/05_cart_pole.pdf
        temp = (
            force + self.polemass_length * np.square(theta_dot) * sintheta
        ) / self.total_mass
        thetaacc = (self.gravity * sintheta - costheta * temp) / (
            self.length
            * (4.0 / 3.0 - self.masspole * np.square(costheta) / self.total_mass)
        )
        xacc = temp - self.polemass_length * thetaacc * costheta / self.total_mass

        x = x + self.tau * x_dot
        x_dot = x_dot + self.tau * xacc
        theta = theta + self.tau * theta_dot
        theta_dot = theta_dot + self.tau * thetaacc

        self.state = np.array(
            (x, x_dot, theta, theta_dot, self.target_position), dtype=np.float64
        ) #Aquest estat es diferent respecte al del cartpole original

        terminated = bool(
            x < -self.x_threshold
            or x > self.x_threshold
            or theta < -self.theta_threshold_radians
            or theta > self.theta_threshold_radians
        )

        reward = self.custom_reward(self.target_position, x, theta, terminated)

        if self.render_mode == "human":
            self.render()

        # truncation=False as the time limit is handled by the `TimeLimit` wrapper added during `make`
        self.steps += 1
        if self.steps >= self.max_steps:
            truncated = True
        else:
            truncated = False
        return np.array(self.state, dtype=np.float32), reward, terminated, truncated, {}

    def reset(
        self,
        *,
        seed: Optional[int] = None,
        options: Optional[dict] = None,
    ):

        super().reset(seed=seed)
        self.steps = 0
        # Note that if you use custom reset bounds, it may lead to out-of-bound
        # state/observations.
        low, high = utils.maybe_parse_reset_bounds(
            options, -0.05, 0.05  # default low
        )  # default high

        self.state = self.np_random.uniform(low=low, high=high, size=(4,)).tolist()
        self.steps_beyond_terminated = None

        #Generar posició aleatòria del target i guardar en l'estat
        self.target_position = self.generate_random_target_position()
        self.state.append(self.target_position)

        self.state = np.array(self.state)
        if self.render_mode == "human":
            self.render()
        return np.array(self.state, dtype=np.float32), {}

    def render(self):
        if self.render_mode is None:
            assert self.spec is not None
            gym.logger.warn(
                "You are calling render method without specifying any render mode. "
                "You can specify the render_mode at initialization, "
                f'e.g. gym.make("{self.spec.id}", render_mode="rgb_array")'
            )
            return

        try:
            import pygame
            from pygame import gfxdraw
        except ImportError as e:
            raise DependencyNotInstalled(
                'pygame is not installed, run `pip install "gymnasium[classic-control]"`'
            ) from e

        if self.screen is None:
            pygame.init()
            if self.render_mode == "human":
                pygame.display.init()
                self.screen = pygame.display.set_mode(
                    (self.screen_width, self.screen_height)
                )
            else:  # mode == "rgb_array"
                self.screen = pygame.Surface((self.screen_width, self.screen_height))
        if self.clock is None:
            self.clock = pygame.time.Clock()

        world_width = self.x_threshold * 2
        scale = self.screen_width / world_width
        polewidth = 10.0
        polelen = scale * (2 * self.length)
        cartwidth = 50.0
        cartheight = 30.0
        targetwidth = 10
        targetheight = 10

        if self.state is None:
            return None

        x = self.state

        self.surf = pygame.Surface((self.screen_width, self.screen_height))
        self.surf.fill((255, 255, 255))

        l, r, t, b = -cartwidth / 2, cartwidth / 2, cartheight / 2, -cartheight / 2
        axleoffset = cartheight / 4.0
        cartx = x[0] * scale + self.screen_width / 2.0  # MIDDLE OF CART
        carty = 100  # TOP OF CART
        cart_coords = [(l, b), (l, t), (r, t), (r, b)]
        cart_coords = [(c[0] + cartx, c[1] + carty) for c in cart_coords]
        gfxdraw.aapolygon(self.surf, cart_coords, (0, 0, 0))
        gfxdraw.filled_polygon(self.surf, cart_coords, (0, 0, 0))

        l, r, t, b = (
            -polewidth / 2,
            polewidth / 2,
            polelen - polewidth / 2,
            -polewidth / 2,
        )

        pole_coords = []
        for coord in [(l, b), (l, t), (r, t), (r, b)]:
            coord = pygame.math.Vector2(coord).rotate_rad(-x[2])
            coord = (coord[0] + cartx, coord[1] + carty + axleoffset)
            pole_coords.append(coord)
        gfxdraw.aapolygon(self.surf, pole_coords, (202, 152, 101))
        gfxdraw.filled_polygon(self.surf, pole_coords, (202, 152, 101))

        gfxdraw.aacircle(
            self.surf,
            int(cartx),
            int(carty + axleoffset),
            int(polewidth / 2),
            (129, 132, 203),
        )
        gfxdraw.filled_circle(
            self.surf,
            int(cartx),
            int(carty + axleoffset),
            int(polewidth / 2),
            (129, 132, 203),
        )

        l, r, t, b = (
            -targetwidth / 2,
            targetwidth / 2,
            targetheight / 2,
            -targetheight / 2,
        )
        axleoffset = targetheight / 4.0
        targetx = x[-1] * scale + self.screen_width / 2.0  # MIDDLE OF target
        targety = 90  # TOP OF target
        target_coords = [(l, b), (l, t), (r, t), (r, b)]
        target_coords = [(c[0] + targetx, c[1] + targety) for c in target_coords]
        gfxdraw.aapolygon(self.surf, target_coords, (10, 255, 10))
        gfxdraw.filled_polygon(self.surf, target_coords, (10, 255, 10))

        gfxdraw.hline(self.surf, 0, self.screen_width, carty, (0, 0, 0))

        self.surf = pygame.transform.flip(self.surf, False, True)
        self.screen.blit(self.surf, (0, 0))
        if self.render_mode == "human":
            pygame.event.pump()
            self.clock.tick(self.metadata["render_fps"])
            pygame.display.flip()

        elif self.render_mode == "rgb_array":
            return np.transpose(
                np.array(pygame.surfarray.pixels3d(self.screen)), axes=(1, 0, 2)
            )

    def close(self):
        if self.screen is not None:
            import pygame

            pygame.display.quit()
            pygame.quit()
            self.isopen = False

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong>Exercici 3.2 (1 punt):</strong> Executa un entrenament i analitza els resultats. Per què han anat millor/pitjor? És el que esperaves?
# </div>

# %%
#implementar abans els TODO de l'entorn
#env = CartPoleEnvRandomTarget(render_mode=None,reward_function = 'custom',increased_actions = True,target_desire_factor=1)
#eval_env = CartPoleEnvRandomTarget(render_mode=None,reward_function = 'custom',increased_actions = True,target_desire_factor=1,is_eval = True)

#TODO: Repetir el mateix que en els exercicis anteriors. Callback, model, avaluació inicial, càrrega del millor model i entrenament.
#Al final, analitzar els resultats.

#implementar abans els TODO de l'entorn
# env = CartPoleEnvRandomTarget(render_mode=None,reward_function = 'custom',increased_actions = True,target_desire_factor=1)
# eval_env = CartPoleEnvRandomTarget(render_mode=None,reward_function = 'custom',increased_actions = True,target_desire_factor=1,is_eval = True)

#TODO: Repetir el mateix que en els exercicis anteriors. Callback, model, avaluació inicial, càrrega del millor model i entrenament.
#Al final, analitzar els resultats.
import os
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# Constants
STEPS = 20000
EVAL_FREQ = 2000
EVAL_EPISODES = 18

# Crear l'entorn amb les opcions especificades
env = CartPoleEnvRandomTarget(render_mode=None, reward_function='custom', increased_actions=True, target_desire_factor=1)
eval_env = CartPoleEnvRandomTarget(render_mode=None, reward_function='custom', increased_actions=True, target_desire_factor=1, is_eval=True)

# Callback for evaluation
callback = EvalCallback(
    eval_env=DummyVecEnv([lambda: eval_env]),
    best_model_save_path="./best_model/",
    log_path="./logs/",
    eval_freq=EVAL_FREQ, 
    n_eval_episodes=EVAL_EPISODES,
    deterministic=True,
    render=False
)

# Define PPO model
model = PPO(
    "MlpPolicy", 
    env, 
    verbose=1, 
    tensorboard_log="./ppo_cartpole_tensorboard/"
)

# Avaluació inicial
initial_eval = evaluate_policy(
    model,
    DummyVecEnv([lambda: eval_env]),
    n_eval_episodes=EVAL_EPISODES,
    deterministic=True
)
print(f"Initial evaluation: {initial_eval}")
print(f"Avaluació inicial - Mitjana de recompensa: {initial_eval[0]}")

# Entrenament
model.learn(total_timesteps=STEPS, callback=callback)

# Càrrega del millor model desat
best_model_path = "./best_model/best_model.zip"

if os.path.exists(best_model_path):
    model = PPO.load(best_model_path)
    print("El millor model ha estat carregat correctament.")
else:
    raise FileNotFoundError(f"No s'ha trobat el model a {best_model_path}")

# Avaluació final del millor model
final_eval = evaluate_policy(
    model,
    DummyVecEnv([lambda: eval_env]),
    n_eval_episodes=EVAL_EPISODES,
    return_episode_rewards=True
)

# Càlcul de la recompensa mitjana i passos mitjans
total_reward = sum(final_eval[0])  # Suma de totes les recompenses
total_steps = sum(final_eval[1])   # Suma de tots els passos

average_reward = total_reward / EVAL_EPISODES
average_steps = total_steps / EVAL_EPISODES
print(f'Best model evaluation: {final_eval}')
print(f"Recompensa mitjana: {average_reward}, Passos mitjans per episodi: {average_steps}")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Initial evaluation: (26.04329349597295, 31.02649571432631)
# Avaluació inicial - Mitjana de recompensa: 26.04329349597295
# Logging to ./ppo_cartpole_tensorboard/PPO_8
# Eval num_timesteps=2000, episode_reward=26.26 +/- 27.45
# Episode length: 28.11 +/- 27.07
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 28.1     |
# |    mean_reward     | 26.3     |
# | time/              |          |
# |    total_timesteps | 2000     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.4     |
# |    ep_rew_mean     | 22.7     |
# | time/              |          |
# |    fps             | 1400     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Eval num_timesteps=4000, episode_reward=55.66 +/- 27.06
# Episode length: 61.00 +/- 28.62
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 61          |
# |    mean_reward          | 55.7        |
# | time/                   |             |
# |    total_timesteps      | 4000        |
# | train/                  |             |
# |    approx_kl            | 0.007516724 |
# |    clip_fraction        | 0.0637      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | -0.00108    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.83        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 49.7        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.1     |
# |    ep_rew_mean     | 27.7     |
# | time/              |          |
# |    fps             | 956      |
# |    iterations      | 2        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Eval num_timesteps=6000, episode_reward=41.86 +/- 29.22
# Episode length: 45.06 +/- 28.13
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 45.1        |
# |    mean_reward          | 41.9        |
# | time/                   |             |
# |    total_timesteps      | 6000        |
# | train/                  |             |
# |    approx_kl            | 0.008213054 |
# |    clip_fraction        | 0.0671      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | 0.0293      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00839    |
# |    value_loss           | 36.8        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.1     |
# |    ep_rew_mean     | 29.4     |
# | time/              |          |
# |    fps             | 876      |
# |    iterations      | 3        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 6144     |
# ---------------------------------
# Eval num_timesteps=8000, episode_reward=84.20 +/- 18.90
# Episode length: 95.94 +/- 20.45
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 95.9        |
# |    mean_reward          | 84.2        |
# | time/                   |             |
# |    total_timesteps      | 8000        |
# | train/                  |             |
# |    approx_kl            | 0.010364216 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.195       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.3        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0157     |
# |    value_loss           | 34.4        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 37       |
# |    ep_rew_mean     | 33.5     |
# | time/              |          |
# |    fps             | 815      |
# |    iterations      | 4        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 8192     |
# ---------------------------------
# Eval num_timesteps=10000, episode_reward=156.81 +/- 61.27
# Episode length: 178.72 +/- 55.23
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 179         |
# |    mean_reward          | 157         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.012305338 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.35        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19          |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0205     |
# |    value_loss           | 40.2        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47       |
# |    ep_rew_mean     | 42.2     |
# | time/              |          |
# |    fps             | 746      |
# |    iterations      | 5        |
# |    time_elapsed    | 13       |
# |    total_timesteps | 10240    |
# ---------------------------------
# Eval num_timesteps=12000, episode_reward=208.48 +/- 68.60
# Episode length: 238.17 +/- 83.36
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 238         |
# |    mean_reward          | 208         |
# | time/                   |             |
# |    total_timesteps      | 12000       |
# | train/                  |             |
# |    approx_kl            | 0.010624717 |
# |    clip_fraction        | 0.0902      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.502       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.2        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0195     |
# |    value_loss           | 43.5        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 63.9     |
# |    ep_rew_mean     | 57.1     |
# | time/              |          |
# |    fps             | 688      |
# |    iterations      | 6        |
# |    time_elapsed    | 17       |
# |    total_timesteps | 12288    |
# ---------------------------------
# Eval num_timesteps=14000, episode_reward=199.59 +/- 77.13
# Episode length: 235.50 +/- 80.30
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 236         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 14000       |
# | train/                  |             |
# |    approx_kl            | 0.011647151 |
# |    clip_fraction        | 0.0926      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | 0.584       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.1        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0174     |
# |    value_loss           | 44.2        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 79.4     |
# |    ep_rew_mean     | 70.8     |
# | time/              |          |
# |    fps             | 652      |
# |    iterations      | 7        |
# |    time_elapsed    | 21       |
# |    total_timesteps | 14336    |
# ---------------------------------
# Eval num_timesteps=16000, episode_reward=312.33 +/- 72.10
# Episode length: 349.61 +/- 90.48
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 350         |
# |    mean_reward          | 312         |
# | time/                   |             |
# |    total_timesteps      | 16000       |
# | train/                  |             |
# |    approx_kl            | 0.008124059 |
# |    clip_fraction        | 0.0988      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | 0.702       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.4         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00952    |
# |    value_loss           | 29.8        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93.2     |
# |    ep_rew_mean     | 82.5     |
# | time/              |          |
# |    fps             | 607      |
# |    iterations      | 8        |
# |    time_elapsed    | 26       |
# |    total_timesteps | 16384    |
# ---------------------------------
# Eval num_timesteps=18000, episode_reward=365.79 +/- 94.16
# Episode length: 411.56 +/- 91.81
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 412         |
# |    mean_reward          | 366         |
# | time/                   |             |
# |    total_timesteps      | 18000       |
# | train/                  |             |
# |    approx_kl            | 0.007872638 |
# |    clip_fraction        | 0.0646      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.79        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00788    |
# |    value_loss           | 16          |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 113      |
# |    ep_rew_mean     | 101      |
# | time/              |          |
# |    fps             | 571      |
# |    iterations      | 9        |
# |    time_elapsed    | 32       |
# |    total_timesteps | 18432    |
# ---------------------------------
# Eval num_timesteps=20000, episode_reward=364.16 +/- 67.74
# Episode length: 418.28 +/- 77.07
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 418         |
# |    mean_reward          | 364         |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.008459138 |
# |    clip_fraction        | 0.0739      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.78        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 32.6        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 130      |
# |    ep_rew_mean     | 116      |
# | time/              |          |
# |    fps             | 545      |
# |    iterations      | 10       |
# |    time_elapsed    | 37       |
# |    total_timesteps | 20480    |
# ---------------------------------
# El millor model ha estat carregat correctament.
# Best model evaluation: ([408.22108721733093, 340.3805261850357, 482.39379501342773, 497.45001542568207, 351.9888429045677, 282.01745343208313, 268.17225009202957, 443.7441917061806, 253.61160868406296, 398.28006237745285, 431.95273345708847, 452.766079723835, 494.97279036045074, 493.4593799710274, 281.3464489579201, 328.88932609558105, 447.6196684241295, 226.21416544914246], [500, 367, 500, 500, 364, 311, 328, 500, 302, 500, 500, 500, 500, 500, 310, 393, 497, 266])
# Recompensa mitjana: 382.41557919316824, Passos mitjans per episodi: 424.3333333333333

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>Comentari:</strong>
# <br><br>
#
# Després de realitzar l'entrenament amb els canvis aplicats augmentant les possibles accions a realitzar i continuant amb el paràmetre 'target_desire_factor=1', podem veure que els resultats són molt més bons. Tant la recompensa mitjana com el nombre de passos mitjans per episodi s'han disparat.
#
# Realment esperava una millora significativa, ja que tenir major quantitat de possibles moviments ens porta a tenir un millor control del CartPole i com a resultat una millora en el rendiment en general. Tot i això, no pensava que l'increment en la millora fos tan gran.
# </div>

# %% [markdown]
# # 4. Cerca d'hiperparàmetres (1.5 pts)

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong>Exercici 4.1 (1 punt):</strong> Utilitzant l'entorn amb desire_factor = 1 i amb les accions per defecte (no ampliades), busca els hiperparàmetres del model perquè aquest aprengui en menys de 10 mil passos. Us donem algunes pistes sobre el rang de valors que val la pena explorar:
#     <ul>
#     <li>gamma = (0.9,0.999). Es recomana cerca en escala logarítmica</li>
#     <li>max_grad_norm = (0.3,5.0). Es recomana cerca en escala logarítmica</li>
#     <li>n_steps = (8,32)</li>
#     <li>learning_rate = (1e-5,1e-1). Es recomana cerca en escala logarítmica</li>
#     <li>ent_coef = (1e-8,1e-3). Es recomana cerca en escala logarítmica</li>
#     </ul>
#     <strong>Important:</strong> La cerca d'hiperparàmetres s'ha de poder fer en 100 passos, és a dir, només caldria entrenar el model amb 100 combinacions diferents d'hiperparàmetres, res més.
#
# Explica l'estratègia de cerca que s'ha seguit. Si s'utilitza una estratègia dummy tipus grid search, la puntuació màxima serà de 0.5/1 punts. Per aconseguir la màxima puntuació, podeu utilitzar frameworks com [optuna](https://optuna.org/#code_examples) per fer l'optimització d'hiperparàmetres.
# </div>

# %%
STEPS = 10_000 #BAIXEM ELS STEPS A 10_000 per fer la cerca més ràpida
EVAL_EPISODES = 18
EVAL_FREQ = 2_000
N_TRIALS = 100  #Només farem 100 trials amb diferents combinacions d'hiperparàmetres

# %%
#eval_env = CartPoleEnvRandomTarget(render_mode=None,reward_function = 'custom',increased_actions = False,target_desire_factor=1,is_eval = True)

import random
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy

#Define the evaluation environment
eval_env = CartPoleEnvRandomTarget(render_mode=None, reward_function='custom', increased_actions=False, target_desire_factor=1, is_eval=True)

#Define the ranges for hyperparameters
gamma_range = (0.9, 0.999)
max_grad_norm_range = (0.3, 5.0)
n_steps_range = (8, 32)
learning_rate_range = (1e-5, 1e-1)
ent_coef_range = (1e-8, 1e-3)


#Number of trials
N_TRIALS = 100

#Function to sample hyperparameters
def sample_hyperparameters():
    gamma = random.uniform(*gamma_range)
    max_grad_norm = random.uniform(*max_grad_norm_range)
    n_steps = random.randint(*n_steps_range)
    learning_rate = random.uniform(*learning_rate_range)
    ent_coef = random.uniform(*ent_coef_range)
    return gamma, max_grad_norm, n_steps, learning_rate, ent_coef

#Perform random search
best_mean_reward = -float('inf')
best_hyperparams = None

for trial in range(N_TRIALS):
    gamma, max_grad_norm, n_steps, learning_rate, ent_coef = sample_hyperparameters()
    
    #Create the training environment
    train_env = make_vec_env(lambda: CartPoleEnvRandomTarget(render_mode=None, reward_function='custom', increased_actions=False, target_desire_factor=1), n_envs=1)
    
    #Create the PPO model with the sampled hyperparameters
    model = PPO('MlpPolicy', train_env, gamma=gamma, max_grad_norm=max_grad_norm, n_steps=n_steps, learning_rate=learning_rate, ent_coef=ent_coef, verbose=0)
    
    #Train the model
    model.learn(total_timesteps=10_000)
    
    #Evaluate the model
    mean_reward, _ = evaluate_policy(model, eval_env, n_eval_episodes=EVAL_EPISODES)
    
    #Update the best hyperparameters if the current ones are better
    if mean_reward > best_mean_reward:
        best_mean_reward = mean_reward
        best_hyperparams = (gamma, max_grad_norm, n_steps, learning_rate, ent_coef)

#Print the best hyperparameters
print('Best hyperparameters:', best_hyperparams)
# Out:
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 31`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 31
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=31 and n_envs=1)
#   warnings.warn(
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 9`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 9
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=9 and n_envs=1)
#   warnings.warn(
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 26`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 26
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=26 and n_envs=1)
#   warnings.warn(
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 20`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 20
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=20 and n_envs=1)
#   warnings.warn(
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 17`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 17
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=17 and n_envs=1)
#   warnings.warn(
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 24`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 24
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=24 and n_envs=1)
#   warnings.warn(
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 21`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 21
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=21 and n_envs=1)
#   warnings.warn(
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 28`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 28
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=28 and n_envs=1)
#   warnings.warn(
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 23`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 23
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=23 and n_envs=1)
#   warnings.warn(
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 29`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 29
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=29 and n_envs=1)
#   warnings.warn(
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 30`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 30
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=30 and n_envs=1)
#   warnings.warn(
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 11`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 11
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=11 and n_envs=1)
#   warnings.warn(
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 22`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 22
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=22 and n_envs=1)
#   warnings.warn(
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 18`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 18
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=18 and n_envs=1)
#   warnings.warn(
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 14`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 14
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=14 and n_envs=1)
#   warnings.warn(
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 32`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 32
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=32 and n_envs=1)
#   warnings.warn(
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 25`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 25
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=25 and n_envs=1)
#   warnings.warn(
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 13`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 13
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=13 and n_envs=1)
#   warnings.warn(
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 15`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 15
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=15 and n_envs=1)
#   warnings.warn(
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 10`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 10
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=10 and n_envs=1)
#   warnings.warn(
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 16`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 16
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=16 and n_envs=1)
#   warnings.warn(
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 27`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 27
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=27 and n_envs=1)
#   warnings.warn(
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 8`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 8
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=8 and n_envs=1)
#   warnings.warn(
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 12`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 12
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=12 and n_envs=1)
#   warnings.warn(
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 19`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 19
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=19 and n_envs=1)
#   warnings.warn(
# Best hyperparameters: (0.9468236588380935, 4.894034448865782, 25, 0.0017854305116525432, 0.0006231141896977283)

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>Comentari:</strong>
# <br><br>
# Per tal de cercar els hiperparàmetres hem utilitzat una Random Search. Aquest mètode cerca de forma aleatòria dins d'uns intervals establerts específics. Després de l'execució d'aquest mètode trobem que tots els valors obtinguts es troben dins dels intervals establerts.
# </div>

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong>Exercici 4.2 (0.5 punts):</strong> Ara torna a entrenar un model durant 30_000 passos i analitza els resultats obtinguts.
# </div>

# %%
STEPS = 30_000
env = CartPoleEnvRandomTarget(render_mode=None,reward_function = 'custom',increased_actions = False,target_desire_factor=1)
eval_env = CartPoleEnvRandomTarget(render_mode=None,reward_function = 'custom',increased_actions = False,target_desire_factor=1,is_eval = True)

#TODO: Repetir el mateix que en els exercicis anteriors. Callback, model, avaluació inicial, càrrega del millor model i entrenament.
#Recordeu fer servir els millors hiperparametres trobats
#Al final, analitzar els resultats.

import os
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.env_util import make_vec_env

# Millors hiperparàmetres trobats
best_hyperparams = {
    "gamma": 0.9468236588380935,
    "max_grad_norm": 4.894034448865782,
    "n_steps": 25,
    "learning_rate": 0.0017854305116525432,
    "ent_coef": 0.0006231141896977283,
}

# Constants
STEPS = 30_000
EVAL_EPISODES = 18
EVAL_FREQ = 5_000

# Crear els entorns d'entrenament i avaluació
env = make_vec_env(lambda: CartPoleEnvRandomTarget(render_mode=None, reward_function='custom', increased_actions=False, target_desire_factor=1), n_envs=1)
eval_env = CartPoleEnvRandomTarget(render_mode=None, reward_function='custom', increased_actions=False, target_desire_factor=1, is_eval=True)

# Callback per avaluar durant l'entrenament
callback = EvalCallback(
    eval_env=DummyVecEnv([lambda: eval_env]),
    best_model_save_path="./best_model_30000/",
    log_path="./logs_30000/",
    eval_freq=EVAL_FREQ, 
    n_eval_episodes=EVAL_EPISODES,
    deterministic=True,
    render=False
)

# Crear i configurar el model PPO
model = PPO(
    "MlpPolicy",
    env,
    gamma=best_hyperparams["gamma"],
    max_grad_norm=best_hyperparams["max_grad_norm"],
    n_steps=best_hyperparams["n_steps"],
    learning_rate=best_hyperparams["learning_rate"],
    ent_coef=best_hyperparams["ent_coef"],
    verbose=1,
    tensorboard_log="./ppo_cartpole_tensorboard_30000/"
)

# Avaluació inicial abans de l'entrenament
initial_mean_reward, initial_mean_length = evaluate_policy(
    model,
    eval_env,
    n_eval_episodes=EVAL_EPISODES,
    deterministic=True,
    return_episode_rewards=True
)
print(f"Avaluació inicial - Recompensa mitjana: {initial_mean_reward}, Passos mitjans per episodi: {initial_mean_length}")

# Entrenament del model
model.learn(total_timesteps=STEPS, callback=callback)

# Càrrega del millor model desat
best_model_path = "./best_model_30000/best_model.zip"
if os.path.exists(best_model_path):
    model = PPO.load(best_model_path)
    print("El millor model ha estat carregat correctament.")
else:
    raise FileNotFoundError(f"No s'ha trobat el model a {best_model_path}")

# Avaluació final del millor model
final_rewards, final_lengths = evaluate_policy(
    model,
    eval_env,
    n_eval_episodes=EVAL_EPISODES,
    return_episode_rewards=True
)

# Resultats finals
average_reward = sum(final_rewards) / len(final_rewards)
average_steps = sum(final_lengths) / len(final_lengths)

print(f"Avaluació final - Recompensa mitjana: {average_reward}, Passos mitjans per episodi: {average_steps}")
# Out:
# Using cpu device
# Avaluació inicial - Recompensa mitjana: [30.46279925107956, 32.99761152267456, 56.91296458244324, 15.897740185260773, 11.092984020709991, 10.361815571784973, 13.05851298570633, 11.156120479106903, 23.243831634521484, 37.247851848602295, 39.99673545360565, 39.20028817653656, 14.974602997303009, 17.635996222496033, 8.955252051353455, 8.862250685691833, 13.594478368759155, 22.335206031799316], Passos mitjans per episodi: [31, 33, 58, 17, 13, 14, 18, 13, 25, 38, 40, 40, 16, 21, 12, 12, 16, 24]
# Logging to ./ppo_cartpole_tensorboard_30000/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19       |
# |    ep_rew_mean     | 18.2     |
# | time/              |          |
# |    fps             | 1226     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 25       |
# ---------------------------------
# C:\Users\xavim\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 25`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 25
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=25 and n_envs=1)
#   warnings.warn(
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.7        |
# |    ep_rew_mean          | 15.1        |
# | time/                   |             |
# |    fps                  | 686         |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 50          |
# | train/                  |             |
# |    approx_kl            | 0.015820231 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | 0.00442     |
# |    learning_rate        | 0.00179     |
# |    loss                 | 9.56        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00741    |
# |    value_loss           | 24.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.2        |
# |    ep_rew_mean          | 14.5        |
# | time/                   |             |
# |    fps                  | 589         |
# |    iterations           | 3           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 75          |
# | train/                  |             |
# |    approx_kl            | 0.023687357 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | 0.06        |
# |    learning_rate        | 0.00179     |
# |    loss                 | 5.52        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0218     |
# |    value_loss           | 14.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14.8         |
# |    ep_rew_mean          | 14           |
# | time/                   |              |
# |    fps                  | 551          |
# |    iterations           | 4            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 100          |
# | train/                  |              |
# |    approx_kl            | 0.0011987757 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.691       |
# |    explained_variance   | -0.903       |
# |    learning_rate        | 0.00179      |
# |    loss                 | 7.64         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 17.5         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 14.9       |
# |    ep_rew_mean          | 13.6       |
# | time/                   |            |
# |    fps                  | 533        |
# |    iterations           | 5          |
# |    time_elapsed         | 0          |
# |    total_timesteps      | 125        |
# | train/                  |            |
# |    approx_kl            | 0.02448751 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.69      |
# |    explained_variance   | 0.0497     |
# |    learning_rate        | 0.00179    |
# |    loss                 | 9.92       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0171    |
# |    value_loss           | 23.5       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14.8         |
# |    ep_rew_mean          | 13.7         |
# | time/                   |              |
# |    fps                  | 516          |
# |    iterations           | 6            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 150          |
# | train/                  |              |
# |    approx_kl            | 0.0034519804 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.68        |
# |    explained_variance   | -3.27        |
# |    learning_rate        | 0.00179      |
# |    loss                 | 6.63         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00863     |
# |    value_loss           | 21.4         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 14.8       |
# |    ep_rew_mean          | 13.7       |
# | time/                   |            |
# |    fps                  | 510        |
# |    iterations           | 7          |
# |    time_elapsed         | 0          |
# |    total_timesteps      | 175        |
# | train/                  |            |
# |    approx_kl            | 0.01766839 |
# |    clip_fraction        | 0.1        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.69      |
# |    explained_variance   | 0.0792     |
# |    learning_rate        | 0.00179    |
# |    loss                 | 3.73       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0144    |
# |    value_loss           | 10.2       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16.3         |
# |    ep_rew_mean          | 15.2         |
# | time/                   |              |
# |    fps                  | 505          |
# |    iterations           | 8            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 200          |
# | train/                  |              |
# |    approx_kl            | 0.0058780764 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.682       |
# |    explained_variance   | -0.667       |
# |    learning_rate        | 0.00179      |
# |    loss                 | 14.8         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0112      |
# |    value_loss           | 35.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.8        |
# |    ep_rew_mean          | 15.7        |
# | time/                   |             |
# |    fps                  | 498         |
# |    iterations           | 9           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 225         |
# | train/                  |             |
# |    approx_kl            | 0.015961206 |
# |    clip_fraction        | 0.052       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.678      |
# |    explained_variance   | -0.21       |
# |    learning_rate        | 0.00179     |
# |    loss                 | 1.84        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0212     |
# |    value_loss           | 6.36        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.3        |
# |    ep_rew_mean          | 16.2        |
# | time/                   |             |
# |    fps                  | 492         |
# |    iterations           | 10          |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 250         |
# | train/                  |             |
# |    approx_kl            | 0.013965435 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | -0.363      |
# |    learning_rate        | 0.00179     |
# |    loss                 | 3.38        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00294    |
# |    value_loss           | 9.06        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.1        |
# |    ep_rew_mean          | 16.1        |
# | time/                   |             |
# |    fps                  | 486         |
# |    iterations           | 11          |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 275         |
# | train/                  |             |
# |    approx_kl            | 0.021955317 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | -0.0858     |
# |    learning_rate        | 0.00179     |
# |    loss                 | 2.7         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 6.4         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.2        |
# |    ep_rew_mean          | 16          |
# | time/                   |             |
# |    fps                  | 483         |
# |    iterations           | 12          |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 300         |
# | train/                  |             |
# |    approx_kl            | 0.016824977 |
# |    clip_fraction        | 0.048       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | -0.0243     |
# |    learning_rate        | 0.00179     |
# |    loss                 | 4.75        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 10.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.4        |
# |    ep_rew_mean          | 16          |
# | time/                   |             |
# |    fps                  | 479         |
# |    iterations           | 13          |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 325         |
# | train/                  |             |
# |    approx_kl            | 0.028172048 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.659      |
# |    explained_variance   | 0.0861      |
# |    learning_rate        | 0.00179     |
# |    loss                 | 4.2         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0213     |
# |    value_loss           | 13          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 17.9         |
# |    ep_rew_mean          | 16.6         |
# | time/                   |              |
# |    fps                  | 475          |
# |    iterations           | 14           |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 350          |
# | train/                  |              |
# |    approx_kl            | 0.0035861612 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.669       |
# |    explained_variance   | -0.33        |
# |    learning_rate        | 0.00179      |
# |    loss                 | 6.36         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | 0.00145      |
# |    value_loss           | 13.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 18.1         |
# |    ep_rew_mean          | 16.9         |
# | time/                   |              |
# |    fps                  | 472          |
# |    iterations           | 15           |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 375          |
# | train/                  |              |
# |    approx_kl            | 0.0049514268 |
# |    clip_fraction        | 0.008        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.685       |
# |    explained_variance   | -0.0841      |
# |    learning_rate        | 0.00179      |
# |    loss                 | 4.03         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00447     |
# |    value_loss           | 8.82         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 18.7         |
# |    ep_rew_mean          | 17.5         |
# | time/                   |              |
# |    fps                  | 470          |
# |    iterations           | 16           |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 400          |
# | train/                  |              |
# |    approx_kl            | 0.0003056097 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.688       |
# |    explained_variance   | 0.13         |
# |    learning_rate        | 0.00179      |
# |    loss                 | 3.44         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000629    |
# |    value_loss           | 7.88         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 19.2         |
# |    ep_rew_mean          | 18.1         |
# | time/                   |              |
# |    fps                  | 471          |
# |    iterations           | 17           |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 425          |
# | train/                  |              |
# |    approx_kl            | 0.0141507685 |
# |    clip_fraction        | 0.036        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.683       |
# |    explained_variance   | 0.227        |
# |    learning_rate        | 0.00179      |
# |    loss                 | 2.23         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0219      |
# |    value_loss           | 6.35         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.3        |
# |    ep_rew_mean          | 18.2        |
# | time/                   |             |
# |    fps                  | 470         |
# |    iterations           | 18          |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 450         |
# | train/                  |             |
# |    approx_kl            | 0.044518746 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.637      |
# |    explained_variance   | -0.168      |
# |    learning_rate        | 0.00179     |
# |    loss                 | 6.02        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0306     |
# |    value_loss           | 13.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.3        |
# |    ep_rew_mean          | 18.2        |
# | time/                   |             |
# |    fps                  | 469         |
# |    iterations           | 19          |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 475         |
# | train/                  |             |
# |    approx_kl            | 0.062169112 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.557      |
# |    explained_variance   | -0.0135     |
# |    learning_rate        | 0.00179     |
# |    loss                 | 3.37        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0265     |
# |    value_loss           | 8.34        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 18.9        |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 20          |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 500         |
# | train/                  |             |
# |    approx_kl            | 0.054052416 |
# |    clip_fraction        | 0.324       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.592      |
# |    explained_variance   | -0.0188     |
# |    learning_rate        | 0.00179     |
# |    loss                 | 3.11        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0375     |
# |    value_loss           | 8.66        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 20.1       |
# |    ep_rew_mean          | 19         |
# | time/                   |            |
# |    fps                  | 466        |
# |    iterations           | 21         |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 525        |
# | train/                  |            |
# |    approx_kl            | 0.03294552 |
# |    clip_fraction        | 0.288      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.542     |
# |    explained_variance   | -0.104     |
# |    learning_rate        | 0.00179    |
# |    loss                 | 7.66       |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0287    |
# |    value_loss           | 16.4       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 20.3       |
# |    ep_rew_mean          | 19.2       |
# | time/                   |            |
# |    fps                  | 464        |
# |    iterations           | 22         |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 550        |
# | train/                  |            |
# |    approx_kl            | 0.07468962 |
# |    clip_fraction        | 0.344      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.484     |
# |    explained_variance   | -0.00519   |
# |    learning_rate        | 0.00179    |
# |    loss                 | 7.15       |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0333    |
# |    value_loss           | 14.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.3        |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 465         |
# |    iterations           | 23          |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 575         |
# | train/                  |             |
# |    approx_kl            | 0.010643073 |
# |    clip_fraction        | 0.052       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.548      |
# |    explained_variance   | -0.013      |
# |    learning_rate        | 0.00179     |
# |    loss                 | 8.11        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 16.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.1         |
# |    ep_rew_mean          | 21           |
# | time/                   |              |
# |    fps                  | 463          |
# |    iterations           | 24           |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 600          |
# | train/                  |              |
# |    approx_kl            | 0.0050436733 |
# |    clip_fraction        | 0.04         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.588       |
# |    explained_variance   | -0.943       |
# |    learning_rate        | 0.00179      |
# |    loss                 | 0.867        |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00443     |
# |    value_loss           | 3.48         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.1        |
# |    ep_rew_mean          | 21          |
# | time/                   |             |
# |    fps                  | 463         |
# |    iterations           | 25          |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 625         |
# | train/                  |             |
# |    approx_kl            | 0.004158859 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.554      |
# |    explained_variance   | -0.0261     |
# |    learning_rate        | 0.00179     |
# |    loss                 | 13.2        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 28          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.4        |
# |    ep_rew_mean          | 21.4        |
# | time/                   |             |
# |    fps                  | 462         |
# |    iterations           | 26          |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 650         |
# | train/                  |             |
# |    approx_kl            | 0.001067655 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.585      |
# |    explained_variance   | 0.2         |
# |    learning_rate        | 0.00179     |
# |    loss                 | 0.995       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.000428   |
# |    value_loss           | 2.85        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 22.4       |
# |    ep_rew_mean          | 21.4       |
# | time/                   |            |
# |    fps                  | 463        |
# |    iterations           | 27         |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 675        |
# | train/                  |            |
# |    approx_kl            | 0.03685549 |
# |    clip_fraction        | 0.16       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.641     |
# |    explained_variance   | -0.0484    |
# |    learning_rate        | 0.00179    |
# |    loss                 | 5.79       |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0353    |
# |    value_loss           | 12.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.4        |
# |    ep_rew_mean          | 21.4        |
# | time/                   |             |
# |    fps                  | 463         |
# |    iterations           | 28          |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 700         |
# | train/                  |             |
# |    approx_kl            | 0.066147454 |
# |    clip_fraction        | 0.672       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.601      |
# |    explained_variance   | -11.3       |
# |    learning_rate        | 0.00179     |
# |    loss                 | 0.016       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0295     |
# |    value_loss           | 0.186       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 22.4       |
# |    ep_rew_mean          | 21.4       |
# | time/                   |            |
# |    fps                  | 462        |
# |    iterations           | 29         |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 725        |
# | train/                  |            |
# |    approx_kl            | 0.07177718 |
# |    clip_fraction        | 0.492      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.475     |
# |    explained_variance   | -34.4      |
# |    learning_rate        | 0.00179    |
# |    loss                 | 0.0492     |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -5.05e-05  |
# |    value_loss           | 0.171      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 25.7       |
# |    ep_rew_mean          | 23.6       |
# | time/                   |            |
# |    fps                  | 462        |
# |    iterations           | 30         |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 750        |
# | train/                  |            |
# |    approx_kl            | 0.66390014 |
# |    clip_fraction        | 0.74       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.438     |
# |    explained_variance   | -0.956     |
# |    learning_rate        | 0.00179    |
# |    loss                 | -0.0743    |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.093     |
# |    value_loss           | 0.132      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 25.7       |
# |    ep_rew_mean          | 23.6       |
# | time/                   |            |
# |    fps                  | 462        |
# |    iterations           | 31         |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 775        |
# | train/                  |            |
# |    approx_kl            | 0.04143516 |
# |    clip_fraction        | 0.252      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.501     |
# |    explained_variance   | 0.00246    |
# |    learning_rate        | 0.00179    |
# |    loss                 | 9          |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.000207  |
# |    value_loss           | 24.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.7        |
# |    ep_rew_mean          | 23.6        |
# | time/                   |             |
# |    fps                  | 462         |
# |    iterations           | 32          |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 800         |
# | train/                  |             |
# |    approx_kl            | 0.024612922 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.521      |
# |    explained_variance   | -0.179      |
# |    learning_rate        | 0.00179     |
# |    loss                 | 2.35        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0209     |
# |    value_loss           | 6.02        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 25.7          |
# |    ep_rew_mean          | 23.6          |
# | time/                   |               |
# |    fps                  | 461           |
# |    iterations           | 33            |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 825           |
# | train/                  |               |
# |    approx_kl            | 0.00062873244 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.594        |
# |    explained_variance   | -0.276        |
# |    learning_rate        | 0.00179       |
# |    loss                 | 0.65          |
# |    n_updates            | 320           |
# |    policy_gradient_loss | 0.000772      |
# |    value_loss           | 3.01          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.1         |
# |    ep_rew_mean          | 26.1         |
# | time/                   |              |
# |    fps                  | 459          |
# |    iterations           | 34           |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 850          |
# | train/                  |              |
# |    approx_kl            | 0.0026355183 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.601       |
# |    explained_variance   | -0.109       |
# |    learning_rate        | 0.00179      |
# |    loss                 | 0.146        |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000608    |
# |    value_loss           | 1.24         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.7         |
# |    ep_rew_mean          | 25.7         |
# | time/                   |              |
# |    fps                  | 459          |
# |    iterations           | 35           |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 875          |
# | train/                  |              |
# |    approx_kl            | 0.0075734104 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.556       |
# |    explained_variance   | -0.327       |
# |    learning_rate        | 0.00179      |
# |    loss                 | 21.1         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0061      |
# |    value_loss           | 42.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.7         |
# |    ep_rew_mean          | 25.7         |
# | time/                   |              |
# |    fps                  | 459          |
# |    iterations           | 36           |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 900          |
# | train/                  |              |
# |    approx_kl            | 0.0008007133 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.585       |
# |    explained_variance   | 0.384        |
# |    learning_rate        | 0.00179      |
# |    loss                 | 5.42         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 0.00017      |
# |    value_loss           | 17.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.7         |
# |    ep_rew_mean          | 25.7         |
# | time/                   |              |
# |    fps                  | 459          |
# |    iterations           | 37           |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 925          |
# | train/                  |              |
# |    approx_kl            | 0.0005942464 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.575       |
# |    explained_variance   | 0.334        |
# |    learning_rate        | 0.00179      |
# |    loss                 | 0.885        |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0024      |
# |    value_loss           | 2.45         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.2        |
# |    ep_rew_mean          | 27.2        |
# | time/                   |             |
# |    fps                  | 458         |
# |    iterations           | 38          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 950         |
# | train/                  |             |
# |    approx_kl            | 0.057025842 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.554      |
# |    explained_variance   | 0.654       |
# |    learning_rate        | 0.00179     |
# |    loss                 | 0.258       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0166     |
# |    value_loss           | 0.776       |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 29.2          |
# |    ep_rew_mean          | 27.2          |
# | time/                   |               |
# |    fps                  | 458           |
# |    iterations           | 39            |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 975           |
# | train/                  |               |
# |    approx_kl            | 0.00035561918 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.557        |
# |    explained_variance   | 0.325         |
# |    learning_rate        | 0.00179       |
# |    loss                 | 8.74          |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.000503     |
# |    value_loss           | 25.2          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.2        |
# |    ep_rew_mean          | 27.2        |
# | time/                   |             |
# |    fps                  | 457         |
# |    iterations           | 40          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1000        |
# | train/                  |             |
# |    approx_kl            | 0.013695326 |
# |    clip_fraction        | 0.064       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.572      |
# |    explained_variance   | -0.358      |
# |    learning_rate        | 0.00179     |
# |    loss                 | 0.0611      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00374    |
# |    value_loss           | 0.315       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.5        |
# |    ep_rew_mean          | 28.6        |
# | time/                   |             |
# |    fps                  | 457         |
# |    iterations           | 41          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1025        |
# | train/                  |             |
# |    approx_kl            | 0.012150977 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.53       |
# |    explained_variance   | -0.386      |
# |    learning_rate        | 0.00179     |
# |    loss                 | 0.00877     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0097     |
# |    value_loss           | 0.0933      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.5        |
# |    ep_rew_mean          | 28.6        |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 42          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1050        |
# | train/                  |             |
# |    approx_kl            | 0.005336112 |
# |    clip_fraction        | 0.02        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.557      |
# |    explained_variance   | -0.145      |
# |    learning_rate        | 0.00179     |
# |    loss                 | 22.7        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.0102      |
# |    value_loss           | 47.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.5        |
# |    ep_rew_mean          | 28.6        |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 43          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1075        |
# | train/                  |             |
# |    approx_kl            | 0.025770599 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.473      |
# |    explained_variance   | -0.672      |
# |    learning_rate        | 0.00179     |
# |    loss                 | 0.214       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.707       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.5        |
# |    ep_rew_mean          | 28.6        |
# | time/                   |             |
# |    fps                  | 455         |
# |    iterations           | 44          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1100        |
# | train/                  |             |
# |    approx_kl            | 0.014269687 |
# |    clip_fraction        | 0.048       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.536      |
# |    explained_variance   | -0.769      |
# |    learning_rate        | 0.00179     |
# |    loss                 | 0.0278      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00941    |
# |    value_loss           | 0.207       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.5         |
# |    ep_rew_mean          | 28.6         |
# | time/                   |              |
# |    fps                  | 454          |
# |    iterations           | 45           |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 1125         |
# | train/                  |              |
# |    approx_kl            | 0.0052630366 |
# |    clip_fraction        | 0.068        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.469       |
# |    explained_variance   | -3.4         |
# |    learning_rate        | 0.00179      |
# |    loss                 | 0.0448       |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 0.000235     |
# |    value_loss           | 0.137        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30.5       |
# |    ep_rew_mean          | 28.6       |
# | time/                   |            |
# |    fps                  | 454        |
# |    iterations           | 46         |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 1150       |
# | train/                  |            |
# |    approx_kl            | 0.01280959 |
# |    clip_fraction        | 0.036      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.512     |
# |    explained_variance   | 0.889      |
# |    learning_rate        | 0.00179    |
# |    loss                 | -0.00457   |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.00813   |
# |    value_loss           | 0.015      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34.4         |
# |    ep_rew_mean          | 32.5         |
# | time/                   |              |
# |    fps                  | 453          |
# |    iterations           | 47           |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 1175         |
# | train/                  |              |
# |    approx_kl            | 0.0081043765 |
# |    clip_fraction        | 0.08         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.463       |
# |    explained_variance   | 0.815        |
# |    learning_rate        | 0.00179      |
# |    loss                 | 0.049        |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00782     |
# |    value_loss           | 0.257        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 34.1       |
# |    ep_rew_mean          | 32.2       |
# | time/                   |            |
# |    fps                  | 453        |
# |    iterations           | 48         |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 1200       |
# | train/                  |            |
# |    approx_kl            | 0.03311072 |
# |    clip_fraction        | 0.124      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.441     |
# |    explained_variance   | 0.918      |
# |    learning_rate        | 0.00179    |
# |    loss                 | 0.0712     |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.00188   |
# |    value_loss           | 0.844      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.1        |
# |    ep_rew_mean          | 32.2        |
# | time/                   |             |
# |    fps                  | 453         |
# |    iterations           | 49          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1225        |
# | train/                  |             |
# |    approx_kl            | 0.015482079 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.377      |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.00179     |
# |    loss                 | 0.776       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00978    |
# |    value_loss           | 2.33        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.1        |
# |    ep_rew_mean          | 32.2        |
# | time/                   |             |
# |    fps                  | 453         |
# |    iterations           | 50          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1250        |
# | train/                  |             |
# |    approx_kl            | 0.011179201 |
# |    clip_fraction        | 0.06        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.494      |
# |    explained_variance   | -15.8       |
# |    learning_rate        | 0.00179     |
# |    loss                 | -0.00352    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00469    |
# |    value_loss           | 0.00678     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.1        |
# |    ep_rew_mean          | 32.2        |
# | time/                   |             |
# |    fps                  | 453         |
# |    iterations           | 51          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1275        |
# | train/                  |             |
# |    approx_kl            | 0.030684402 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.479      |
# |    explained_variance   | 0.44        |
# |    learning_rate        | 0.00179     |
# |    loss                 | -0.00796    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00956    |
# |    value_loss           | 0.00113     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 35.6       |
# |    ep_rew_mean          | 33.7       |
# | time/                   |            |
# |    fps                  | 453        |
# |    iterations           | 52         |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 1300       |
# | train/                  |            |
# |    approx_kl            | 0.07243855 |
# |    clip_fraction        | 0.284      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.517     |
# |    explained_variance   | 0.699      |
# |    learning_rate        | 0.00179    |
# |    loss                 | -0.0222    |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.0177    |
# |    value_loss           | 0.000224   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 35.4       |
# |    ep_rew_mean          | 33.3       |
# | time/                   |            |
# |    fps                  | 453        |
# |    iterations           | 53         |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 1325       |
# | train/                  |            |
# |    approx_kl            | 0.01024059 |
# |    clip_fraction        | 0.06       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.496     |
# |    explained_variance   | -0.0307    |
# |    learning_rate        | 0.00179    |
# |    loss                 | 23.6       |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.0196    |
# |    value_loss           | 50.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.1        |
# |    ep_rew_mean          | 33          |
# | time/                   |             |
# |    fps                  | 452         |
# |    iterations           | 54          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1350        |
# | train/                  |             |
# |    approx_kl            | 0.006980245 |
# |    clip_fraction        | 0.016       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.516      |
# |    explained_variance   | -2.24       |
# |    learning_rate        | 0.00179     |
# ...
# |    total_timesteps      | 29575       |
# | train/                  |             |
# |    approx_kl            | 0.042703085 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.361      |
# |    explained_variance   | 0.481       |
# |    learning_rate        | 0.00179     |
# |    loss                 | 0.0021      |
# |    n_updates            | 11820       |
# |    policy_gradient_loss | -0.017      |
# |    value_loss           | 0.0463      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 268         |
# |    ep_rew_mean          | 237         |
# | time/                   |             |
# |    fps                  | 366         |
# |    iterations           | 1184        |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 29600       |
# | train/                  |             |
# |    approx_kl            | 0.043851048 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.598      |
# |    explained_variance   | 0.401       |
# |    learning_rate        | 0.00179     |
# |    loss                 | 3.66        |
# |    n_updates            | 11830       |
# |    policy_gradient_loss | -0.0218     |
# |    value_loss           | 10.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 268         |
# |    ep_rew_mean          | 237         |
# | time/                   |             |
# |    fps                  | 366         |
# |    iterations           | 1185        |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 29625       |
# | train/                  |             |
# |    approx_kl            | 0.033125874 |
# |    clip_fraction        | 0.384       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.45       |
# |    explained_variance   | 0.255       |
# |    learning_rate        | 0.00179     |
# |    loss                 | 2.33        |
# |    n_updates            | 11840       |
# |    policy_gradient_loss | -0.0192     |
# |    value_loss           | 7.72        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 268        |
# |    ep_rew_mean          | 237        |
# | time/                   |            |
# |    fps                  | 366        |
# |    iterations           | 1186       |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 29650      |
# | train/                  |            |
# |    approx_kl            | 0.02856082 |
# |    clip_fraction        | 0.164      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.363     |
# |    explained_variance   | 0.878      |
# |    learning_rate        | 0.00179    |
# |    loss                 | 0.436      |
# |    n_updates            | 11850      |
# |    policy_gradient_loss | -0.0306    |
# |    value_loss           | 1.92       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 268         |
# |    ep_rew_mean          | 237         |
# | time/                   |             |
# |    fps                  | 366         |
# |    iterations           | 1187        |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 29675       |
# | train/                  |             |
# |    approx_kl            | 0.006169063 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.363      |
# |    explained_variance   | 0.00336     |
# |    learning_rate        | 0.00179     |
# |    loss                 | 0.348       |
# |    n_updates            | 11860       |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 2.5         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 268        |
# |    ep_rew_mean          | 237        |
# | time/                   |            |
# |    fps                  | 366        |
# |    iterations           | 1188       |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 29700      |
# | train/                  |            |
# |    approx_kl            | 0.09775767 |
# |    clip_fraction        | 0.124      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.222     |
# |    explained_variance   | 0.475      |
# |    learning_rate        | 0.00179    |
# |    loss                 | 0.316      |
# |    n_updates            | 11870      |
# |    policy_gradient_loss | -0.0184    |
# |    value_loss           | 0.673      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 268       |
# |    ep_rew_mean          | 237       |
# | time/                   |           |
# |    fps                  | 366       |
# |    iterations           | 1189      |
# |    time_elapsed         | 81        |
# |    total_timesteps      | 29725     |
# | train/                  |           |
# |    approx_kl            | 0.2857041 |
# |    clip_fraction        | 0.368     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.277    |
# |    explained_variance   | 0.986     |
# |    learning_rate        | 0.00179   |
# |    loss                 | -0.042    |
# |    n_updates            | 11880     |
# |    policy_gradient_loss | -0.0516   |
# |    value_loss           | 0.0699    |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 268          |
# |    ep_rew_mean          | 237          |
# | time/                   |              |
# |    fps                  | 366          |
# |    iterations           | 1190         |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 29750        |
# | train/                  |              |
# |    approx_kl            | 0.0006202292 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.268       |
# |    explained_variance   | 0.522        |
# |    learning_rate        | 0.00179      |
# |    loss                 | 1.06         |
# |    n_updates            | 11890        |
# |    policy_gradient_loss | 0.00215      |
# |    value_loss           | 6.84         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 268         |
# |    ep_rew_mean          | 237         |
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 1191        |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 29775       |
# | train/                  |             |
# |    approx_kl            | 0.007786076 |
# |    clip_fraction        | 0.096       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.228      |
# |    explained_variance   | -39.8       |
# |    learning_rate        | 0.00179     |
# |    loss                 | 1.27        |
# |    n_updates            | 11900       |
# |    policy_gradient_loss | 0.00504     |
# |    value_loss           | 5.11        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 268         |
# |    ep_rew_mean          | 237         |
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 1192        |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 29800       |
# | train/                  |             |
# |    approx_kl            | 0.022918964 |
# |    clip_fraction        | 0.06        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.127      |
# |    explained_variance   | -1.32       |
# |    learning_rate        | 0.00179     |
# |    loss                 | -0.00791    |
# |    n_updates            | 11910       |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 0.0193      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 268          |
# |    ep_rew_mean          | 237          |
# | time/                   |              |
# |    fps                  | 367          |
# |    iterations           | 1193         |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 29825        |
# | train/                  |              |
# |    approx_kl            | 0.0044496036 |
# |    clip_fraction        | 0.06         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.234       |
# |    explained_variance   | 0.974        |
# |    learning_rate        | 0.00179      |
# |    loss                 | -0.018       |
# |    n_updates            | 11920        |
# |    policy_gradient_loss | -0.0169      |
# |    value_loss           | 0.00592      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 269          |
# |    ep_rew_mean          | 238          |
# | time/                   |              |
# |    fps                  | 367          |
# |    iterations           | 1194         |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 29850        |
# | train/                  |              |
# |    approx_kl            | 0.0002468705 |
# |    clip_fraction        | 0.236        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.255       |
# |    explained_variance   | -19.3        |
# |    learning_rate        | 0.00179      |
# |    loss                 | 0.00278      |
# |    n_updates            | 11930        |
# |    policy_gradient_loss | -0.00981     |
# |    value_loss           | 0.0997       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 269         |
# |    ep_rew_mean          | 238         |
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 1195        |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 29875       |
# | train/                  |             |
# |    approx_kl            | 0.010243296 |
# |    clip_fraction        | 0.028       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.135      |
# |    explained_variance   | -0.0154     |
# |    learning_rate        | 0.00179     |
# |    loss                 | 20.7        |
# |    n_updates            | 11940       |
# |    policy_gradient_loss | -0.00983    |
# |    value_loss           | 53.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 269         |
# |    ep_rew_mean          | 238         |
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 1196        |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 29900       |
# | train/                  |             |
# |    approx_kl            | 0.012867506 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.223      |
# |    explained_variance   | 0.671       |
# |    learning_rate        | 0.00179     |
# |    loss                 | 0.0662      |
# |    n_updates            | 11950       |
# |    policy_gradient_loss | -0.00703    |
# |    value_loss           | 0.328       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 269         |
# |    ep_rew_mean          | 238         |
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 1197        |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 29925       |
# | train/                  |             |
# |    approx_kl            | 0.005757413 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.24       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.00179     |
# |    loss                 | 0.124       |
# |    n_updates            | 11960       |
# |    policy_gradient_loss | -0.0064     |
# |    value_loss           | 0.487       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 269          |
# |    ep_rew_mean          | 238          |
# | time/                   |              |
# |    fps                  | 367          |
# |    iterations           | 1198         |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 29950        |
# | train/                  |              |
# |    approx_kl            | 0.0027970076 |
# |    clip_fraction        | 0.1          |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.214       |
# |    explained_variance   | 0.054        |
# |    learning_rate        | 0.00179      |
# |    loss                 | 0.172        |
# |    n_updates            | 11970        |
# |    policy_gradient_loss | -0.00359     |
# |    value_loss           | 1.07         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 269         |
# |    ep_rew_mean          | 238         |
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 1199        |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 29975       |
# | train/                  |             |
# |    approx_kl            | 0.049079858 |
# |    clip_fraction        | 0.064       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.146      |
# |    explained_variance   | 0.265       |
# |    learning_rate        | 0.00179     |
# |    loss                 | 0.0163      |
# |    n_updates            | 11980       |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 0.181       |
# -----------------------------------------
# Eval num_timesteps=30000, episode_reward=329.94 +/- 178.57
# Episode length: 394.00 +/- 198.31
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 394         |
# |    mean_reward          | 330         |
# | time/                   |             |
# |    total_timesteps      | 30000       |
# | train/                  |             |
# |    approx_kl            | 0.009807501 |
# |    clip_fraction        | 0.008       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.085      |
# |    explained_variance   | 0.666       |
# |    learning_rate        | 0.00179     |
# |    loss                 | 0.00401     |
# |    n_updates            | 11990       |
# |    policy_gradient_loss | -0.00572    |
# |    value_loss           | 0.115       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 269      |
# |    ep_rew_mean     | 238      |
# | time/              |          |
# |    fps             | 354      |
# |    iterations      | 1200     |
# |    time_elapsed    | 84       |
# |    total_timesteps | 30000    |
# ---------------------------------
# El millor model ha estat carregat correctament.
# Avaluació final - Recompensa mitjana: 462.4759341544575, Passos mitjans per episodi: 500.0

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>Comentari:</strong>
# <br><br>
# Després de tornar a entrenar el model utilitzant els hiperparàmetres trobats, obtenim uns molt bons resultats. Recompensa mitjana molt alta completant els episodis. També cal destacar que en aquest punt no es fan servir les 'increased_actions', fet que fa destacar encara més els resultats obtinguts.
# </div>
